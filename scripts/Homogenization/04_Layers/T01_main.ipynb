# %%
import os 
from copy import deepcopy
from Composite.RunFullModel import RunFullModel
join = os.path.join
import numpy as np

# %%
params_composite ={
    "r"         :  0.25,
    "h"         :  0.65,
    "z0"        :  0,
    "density"   : 8,
    "interface_factor"  :  1.2,
    "with_interface"    : False,
    "mirror"            : True,
    "check_jacobian"    : False,
}

params_ccx = {
    "epsilon" : 0.1,
    "x_fixed":False
}
params = {
    "mesh" : params_composite,
    "ccx"  : params_ccx,
}

# %%
r_span = np.linspace(0.20 ,0.27,3)
r_span
# Out:
# array([0.2  , 0.235, 0.27 ])

# %%
for design in ["X","Y"]:
    for j,ir in enumerate(r_span):

        # Generate mesh and RVE
        params_copy = deepcopy(params)
        params_copy["mesh"]["r"] = ir

        root = join("output","r_{:02d}".format(j))
        print("Running case ",root)

        RunFullModel(design,root,params_copy)
# Out:
# Running case  output\r_00
# 	==================================================
# 	Design SX_smooth
# 	==================================================
# Layer With Sign 1 and number 1/1 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX SX_smooth
# 	==================================================
# Input folder: 	 output\r_00\designs\SX_smooth
# Output folder: 	 output\r_00\ccx\SX_smooth
# Running Calculix at:  output\r_00\ccx\SX_smooth
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\Homogenization\04_Layers\output\r_00\ccx\SX_smooth\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  5416
#
# Calculix finished
#
# Running case  output\r_01
# 	==================================================
# 	Design SX_smooth
# 	==================================================
# Layer With Sign 1 and number 1/1 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX SX_smooth
# 	==================================================
# Input folder: 	 output\r_01\designs\SX_smooth
# Output folder: 	 output\r_01\ccx\SX_smooth
# Running Calculix at:  output\r_01\ccx\SX_smooth
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\Homogenization\04_Layers\output\r_01\ccx\SX_smooth\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  9764
#
# Calculix finished
#
# Running case  output\r_02
# 	==================================================
# 	Design SX_smooth
# 	==================================================
# Layer With Sign 1 and number 1/1 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX SX_smooth
# 	==================================================
# Input folder: 	 output\r_02\designs\SX_smooth
# Output folder: 	 output\r_02\ccx\SX_smooth
# Running Calculix at:  output\r_02\ccx\SX_smooth
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\Homogenization\04_Layers\output\r_02\ccx\SX_smooth\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  1572
#
# Calculix finished
#
# Running case  output\r_00
# 	==================================================
# 	Design SY_smooth
# 	==================================================
# Layer With Sign 1 and number 1/1 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX SY_smooth
# 	==================================================
# Input folder: 	 output\r_00\designs\SY_smooth
# Output folder: 	 output\r_00\ccx\SY_smooth
# Running Calculix at:  output\r_00\ccx\SY_smooth
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\Homogenization\04_Layers\output\r_00\ccx\SY_smooth\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  13988
#
# Calculix finished
#
# Running case  output\r_01
# 	==================================================
# 	Design SY_smooth
# 	==================================================
# Layer With Sign 1 and number 1/1 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX SY_smooth
# 	==================================================
# Input folder: 	 output\r_01\designs\SY_smooth
# Output folder: 	 output\r_01\ccx\SY_smooth
# Running Calculix at:  output\r_01\ccx\SY_smooth
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\Homogenization\04_Layers\output\r_01\ccx\SY_smooth\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  17352
#
# Calculix finished
#
# Running case  output\r_02
# 	==================================================
# 	Design SY_smooth
# 	==================================================
# Layer With Sign 1 and number 1/1 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX SY_smooth
# 	==================================================
# Input folder: 	 output\r_02\designs\SY_smooth
# Output folder: 	 output\r_02\ccx\SY_smooth
# Running Calculix at:  output\r_02\ccx\SY_smooth
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\Homogenization\04_Layers\output\r_02\ccx\SY_smooth\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  7060
#
# Calculix finished
