# %%
import os 
from copy import deepcopy
from FEM_traccion.RunFullModel import RunFullModel
import numpy as np
join = os.path.join

A_s = 0.283 # mm^2

# %%
t_l = 0.475 #  Espesor de la capa [mm]
t_n = 2.934

r = 3*t_l/8 
d = (A_s - np.pi*r**2)/(2*r) # Area de la capa [mm^2]
params_composite ={
    "r"         :  r,
    "d"         :  d,
    "h"         :  t_l,
    "z0"        :  0,
    "density"   : 5,
}

params_ccx = {
    "epsilon" : 0.1,
    "x_fixed" : True
}
params = {
    "mesh" : params_composite,
    "ccx"  : params_ccx,
}

# %%
params
# Out:
# {'mesh': {'r': 0.17812499999999998,
#   'd': 0.5145878692019398,
#   'h': 0.475,
#   'z0': 0,
#   'density': 5},
#  'ccx': {'epsilon': 0.1, 'x_fixed': True}}

# %%
1.05/3
# Out:
# 0.35000000000000003

# %%
E_Resina =  637.4322499999998
E_Carbon =  15333.333333333334

params["ccx"]["E_carbon"] = E_Carbon
params["ccx"]["nu"] = 0.3
params["ccx"]["E_resina"] = E_Resina
params["ccx"]["nu_resina"] = 0.3

E_r_linspace = np.linspace(0.5*E_Resina, 1.5*E_Resina, 4)
E_c_linspace = np.linspace(0.5*E_Carbon, 1.5*E_Carbon, 4)

E_r_ms, E_c_ms = np.meshgrid(E_r_linspace, E_c_linspace)

E_pairs = []
for i in range(E_r_ms.shape[0]):
    for j in range(E_r_ms.shape[1]):
        E_pairs.append((E_r_ms[i,j], E_c_ms[i,j]))
E_pairs = np.array(E_pairs)

# %%
# remove output folder if exists
output_folder = "output"
import os
if os.path.exists(output_folder):
    import shutil
    shutil.rmtree(output_folder)

# %%
output = join("output")
RunFullModel("SX",output,params,E_pairs)
# Out:
# 	==================================================
# 	Design SX
# 	==================================================
# Layer number 1/1 done
# Meshing ...
# 	==================================================
# 	CCX SX
# 	==================================================
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_0
# Resina E:  318.7161249999999
# Carbon E:  7666.666666666667
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_0
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_0\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  14208
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_1
# Resina E:  531.1935416666665
# Carbon E:  7666.666666666667
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_1
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_1\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  3392
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_2
# Resina E:  743.6709583333331
# Carbon E:  7666.666666666667
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_2
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_2\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  1156
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_3
# Resina E:  956.1483749999998
# Carbon E:  7666.666666666667
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_3
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_3\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  9972
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_4
# Resina E:  318.7161249999999
# Carbon E:  12777.777777777777
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_4
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_4\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  9260
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_5
# Resina E:  531.1935416666665
# Carbon E:  12777.777777777777
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_5
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_5\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  12520
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_6
# Resina E:  743.6709583333331
# Carbon E:  12777.777777777777
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_6
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_6\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  12424
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_7
# Resina E:  956.1483749999998
# Carbon E:  12777.777777777777
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_7
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_7\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  6716
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_8
# Resina E:  318.7161249999999
# Carbon E:  17888.888888888887
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_8
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_8\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  13500
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_9
# Resina E:  531.1935416666665
# Carbon E:  17888.888888888887
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_9
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_9\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  788
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_10
# Resina E:  743.6709583333331
# Carbon E:  17888.888888888887
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_10
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_10\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  8072
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_11
# Resina E:  956.1483749999998
# Carbon E:  17888.888888888887
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_11
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_11\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  10832
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_12
# Resina E:  318.7161249999999
# Carbon E:  23000.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_12
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_12\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  7012
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_13
# Resina E:  531.1935416666665
# Carbon E:  23000.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_13
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_13\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  7704
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_14
# Resina E:  743.6709583333331
# Carbon E:  23000.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_14
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_14\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  16196
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_15
# Resina E:  956.1483749999998
# Carbon E:  23000.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_15
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\02_Traccion_SX_model_analitico\output\ccx\SX\E_15\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  5268
#
# Calculix finished
