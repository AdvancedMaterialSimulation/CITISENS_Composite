# %%
import os 
from copy import deepcopy
from FEM_traccion.RunFullModel import RunFullModel
import numpy as np
join = os.path.join

A_s = 0.283 # mm^2

# %%
t_l = 0.475 #  Espesor de la capa [mm]
t_n = 2.934

r = 3*t_l/8 
d = (A_s - np.pi*r**2)/(2*r) # Area de la capa [mm^2]
params_composite ={
    "r"         :  r,
    "d"         :  d,
    "h"         :  t_l,
    "z0"        :  0,
    "density"   : 5,
}

params_ccx = {
    "epsilon" : 0.1,
    "x_fixed" : True
}
params = {
    "mesh" : params_composite,
    "ccx"  : params_ccx,
}

# %%
params
# Out:
# {'mesh': {'r': 0.17812499999999998,
#   'd': 0.5145878692019398,
#   'h': 0.475,
#   'z0': 0,
#   'density': 5},
#  'ccx': {'epsilon': 0.1, 'x_fixed': True}}

# %%
1.05/3
# Out:
# 0.35000000000000003

# %%
E_Resina =  3296.06
E_Carbon =  75409.92

params["ccx"]["E_carbon"] = E_Carbon
params["ccx"]["nu"] = 0.3
params["ccx"]["E_resina"] = E_Resina
params["ccx"]["nu_resina"] = 0.3

E_r_linspace = np.linspace(0.5*E_Resina, 1.5*E_Resina, 4)
E_c_linspace = np.linspace(0.5*E_Carbon, 1.5*E_Carbon, 4)

E_r_ms, E_c_ms = np.meshgrid(E_r_linspace, E_c_linspace)

E_pairs = []
for i in range(E_r_ms.shape[0]):
    for j in range(E_r_ms.shape[1]):
        E_pairs.append((E_r_ms[i,j], E_c_ms[i,j]))
E_pairs = np.array(E_pairs)

# %%
# remove output folder if exists
output_folder = "output"
import os
if os.path.exists(output_folder):
    import shutil
    shutil.rmtree(output_folder)

# %%
output = join("output")
RunFullModel("SX",output,params,E_pairs)
# Out:
# 	==================================================
# 	Design SX
# 	==================================================
# Layer number 1/1 done
# Meshing ...
# 	==================================================
# 	CCX SX
# 	==================================================
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\00
# Resina E:  1648.03
# Carbon E:  37704.96
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\00
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\00\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  13752
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\01
# Resina E:  2746.7166666666667
# Carbon E:  37704.96
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\01
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\01\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  9348
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\02
# Resina E:  3845.4033333333336
# Carbon E:  37704.96
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\02
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\02\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  10440
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\03
# Resina E:  4944.09
# Carbon E:  37704.96
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\03
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\03\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  8144
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\04
# Resina E:  1648.03
# Carbon E:  62841.600000000006
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\04
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\04\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  13496
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\05
# Resina E:  2746.7166666666667
# Carbon E:  62841.600000000006
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\05
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\05\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  9348
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\06
# Resina E:  3845.4033333333336
# Carbon E:  62841.600000000006
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\06
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\06\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  2352
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\07
# Resina E:  4944.09
# Carbon E:  62841.600000000006
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\07
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\07\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  14780
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\08
# Resina E:  1648.03
# Carbon E:  87978.24
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\08
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\08\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  12088
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\09
# Resina E:  2746.7166666666667
# Carbon E:  87978.24
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\09
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\09\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  5768
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\10
# Resina E:  3845.4033333333336
# Carbon E:  87978.24
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\10
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\10\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  3928
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\11
# Resina E:  4944.09
# Carbon E:  87978.24
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\11
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\11\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  3396
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\12
# Resina E:  1648.03
# Carbon E:  113114.88
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\12
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\12\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  4124
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\13
# Resina E:  2746.7166666666667
# Carbon E:  113114.88
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\13
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\13\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  6212
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\14
# Resina E:  3845.4033333333336
# Carbon E:  113114.88
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\14
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\14\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  3340
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_\15
# Resina E:  4944.09
# Carbon E:  113114.88
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_\15
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T03_Modelos_1Capa\04_Traccion_SX_model_analitico\output\ccx\SX\E_\15\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  7336
#
# Calculix finished
