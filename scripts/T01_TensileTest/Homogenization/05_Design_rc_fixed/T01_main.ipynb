# %%
import os 
from copy import deepcopy
from Composite.RunFullModel import RunFullModel
join = os.path.join
import numpy as np

# %%
params_composite ={
    "r"         :  0.297,
    "factor_radius": 2,
    "h"         :  0.35,
    "z0"        :  3.073/2,
    "density"   : 8,
    "interface_factor"  :  1.2,
    "with_interface"    : False,
    "mirror"            : True,
    "check_jacobian"    : False,
}

params_ccx = {
    "epsilon" : 0.1,
    "x_fixed" : False
}
params = {
    "mesh" : params_composite,
    "ccx"  : params_ccx,
}

# %%
design = "A"
for design in ["Adouble","B","C","D","E","F"]:
# for design in ["Adouble"]:
    # Generate mesh and RVE
    params_copy = deepcopy(params)
    RunFullModel(design,"output",params_copy)
# Out:
# 	==================================================
# 	Design Adouble
# 	==================================================
# Layer With Sign 1 and number 1/2 done
# Layer With Sign 1 and number 2/2 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX Adouble
# 	==================================================
# Input folder: 	 output\designs\Adouble
# Output folder: 	 output\ccx\Adouble
# Running Calculix at:  output\ccx\Adouble
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\T01_TensileTest\Homogenization\05_Design_rc_fixed\output\ccx\Adouble\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  19920
#
# Calculix finished
#
# 	==================================================
# 	Design B
# 	==================================================
# Layer With Sign 1 and number 1/2 done
# Layer With Sign 1 and number 2/2 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX B
# 	==================================================
# Input folder: 	 output\designs\B
# Output folder: 	 output\ccx\B
# Running Calculix at:  output\ccx\B
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\T01_TensileTest\Homogenization\05_Design_rc_fixed\output\ccx\B\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  14676
#
# Calculix finished
#
# 	==================================================
# 	Design C
# 	==================================================
# Layer With Sign 1 and number 1/2 done
# Layer With Sign 1 and number 2/2 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX C
# 	==================================================
# Input folder: 	 output\designs\C
# Output folder: 	 output\ccx\C
# Running Calculix at:  output\ccx\C
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\T01_TensileTest\Homogenization\05_Design_rc_fixed\output\ccx\C\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  6464
#
# Calculix finished
#
# 	==================================================
# 	Design D
# 	==================================================
# Layer With Sign 1 and number 1/2 done
# Layer With Sign 1 and number 2/2 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX D
# 	==================================================
# Input folder: 	 output\designs\D
# Output folder: 	 output\ccx\D
# Running Calculix at:  output\ccx\D
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\T01_TensileTest\Homogenization\05_Design_rc_fixed\output\ccx\D\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  18208
#
# Calculix finished
#
# 	==================================================
# 	Design E
# 	==================================================
# Layer With Sign 1 and number 1/3 done
# Layer With Sign 1 and number 2/3 done
# Layer With Sign 1 and number 3/3 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX E
# 	==================================================
# Input folder: 	 output\designs\E
# Output folder: 	 output\ccx\E
# Running Calculix at:  output\ccx\E
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\T01_TensileTest\Homogenization\05_Design_rc_fixed\output\ccx\E\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  16216
#
# SUMMARY OF C0NVERGENCE INFORMATION
# Calculix finished
#
# 	==================================================
# 	Design F
# 	==================================================
# Layer With Sign 1 and number 1/3 done
# Layer With Sign 1 and number 2/3 done
# Layer With Sign 1 and number 3/3 done
# Meshing ...
# Optimizing mesh ...
# 	==================================================
# 	CCX F
# 	==================================================
# Input folder: 	 output\designs\F
# Output folder: 	 output\ccx\F
# Running Calculix at:  output\ccx\F
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\T01_TensileTest\Homogenization\05_Design_rc_fixed\output\ccx\F\out.txt
# Command:
#  mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  15836
#
# Calculix finished
