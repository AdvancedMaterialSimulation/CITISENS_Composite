# %%
from validation.FullExperimental import FullExperimental
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = FullExperimental()
df.rename(columns={"v [X,SX,Y,SY]": "delta"}, inplace=True)

# database
layers = df["layers"].values
layers[0] = ["Y","Y"]
df["layers"] = layers

# df = df.iloc[1:]

df.round(3)
# Out:
#      Et [GPa]           % e        Smax [MPa]         Eb [GPa]        t [mm]  \
#          mean    std   mean    std       mean     std     mean    std   mean
# Name
# TFP1    2.886  0.227  0.123  0.010    279.103  14.338   13.201  0.631  5.267
# TFP2    2.259  0.066  0.088  0.003    153.360   0.473    9.870  0.780  4.700
# TFP3    2.000  0.004  0.087  0.002    137.113   4.997    9.222  0.496  4.833
# TFP4    2.451  0.114  0.095  0.005    184.397   1.357   10.182  0.771  4.700
# TFP5    1.627  0.120  0.090  0.014     99.990   9.790    6.143  0.162  5.700
# TFP6    1.740  0.068  0.089  0.010    104.513   7.709    7.798  0.334  5.600
#
#              b [mm]              layers     Vc
#         std    mean    std
# Name
# TFP1  0.058  25.600  0.100       [Y, Y]  0.178
# TFP2  0.000  25.567  0.058       [Y, X]  0.164
# TFP3  0.058  25.400  0.173      [Y, SX]  0.135
# TFP4  0.000  25.667  0.153      [Y, SY]  0.144
# TFP5  0.000  25.167  0.153  [Y, SX, SY]  0.146
# TFP6  0.000  25.033  0.635   [Y, X, SY]  0.180

# %%
df_old = df.copy()

df_Et = df["Et [GPa]"]["mean"]
df_Eb = df["Eb [GPa]"]["mean"]
df_t = df["t [mm]"]["mean"]
df_b = df["b [mm]"]["mean"]

df = df.drop(columns=["Et [GPa]", "Eb [GPa]", "t [mm]", "b [mm]"],level=0)
df["Et [GPa]"] = df_Et
df["Eb [GPa]"] = df_Eb
df["t [mm]"] = df_t
df["b [mm]"] = df_b
df
# Out:
#            % e            Smax [MPa]                  layers     Vc  Et [GPa]  \
#           mean       std        mean        std
# Name
# TFP1  0.123306  0.009827  279.103333  14.337700       [Y, Y]  0.178  2.885509
# TFP2  0.087556  0.002840  153.360000   0.473181       [Y, X]  0.164  2.258503
# TFP3  0.087444  0.002164  137.113333   4.996812      [Y, SX]  0.135  2.000437
# TFP4  0.095472  0.005491  184.396667   1.356515      [Y, SY]  0.144  2.451362
# TFP5  0.089889  0.013757   99.990000   9.790138  [Y, SX, SY]  0.146  1.626582
# TFP6  0.089083  0.010304  104.513333   7.708893   [Y, X, SY]  0.180  1.739870
#
#        Eb [GPa]    t [mm]     b [mm]
#
# Name
# TFP1  13.201050  5.266667  25.600000
# TFP2   9.869501  4.700000  25.566667
# TFP3   9.222003  4.833333  25.400000
# TFP4  10.181815  4.700000  25.666667
# TFP5   6.143105  5.700000  25.166667
# TFP6   7.798060  5.600000  25.033333

# %% [markdown]
# ### Experimental Data

# %%
df_old
# Out:
#       Et [GPa]                 % e            Smax [MPa]             \
#           mean       std      mean       std        mean        std
# Name
# TFP1  2.885509  0.227295  0.123306  0.009827  279.103333  14.337700
# TFP2  2.258503  0.065626  0.087556  0.002840  153.360000   0.473181
# TFP3  2.000437  0.004435  0.087444  0.002164  137.113333   4.996812
# TFP4  2.451362  0.114353  0.095472  0.005491  184.396667   1.356515
# TFP5  1.626582  0.120272  0.089889  0.013757   99.990000   9.790138
# TFP6  1.739870  0.067515  0.089083  0.010304  104.513333   7.708893
#
#        Eb [GPa]              t [mm]               b [mm]            \
#            mean       std      mean       std       mean       std
# Name
# TFP1  13.201050  0.630858  5.266667  0.057735  25.600000  0.100000
# TFP2   9.869501  0.780113  4.700000  0.000000  25.566667  0.057735
# TFP3   9.222003  0.495965  4.833333  0.057735  25.400000  0.173205
# TFP4  10.181815  0.770635  4.700000  0.000000  25.666667  0.152753
# TFP5   6.143105  0.161637  5.700000  0.000000  25.166667  0.152753
# TFP6   7.798060  0.334186  5.600000  0.000000  25.033333  0.635085
#
#            layers     Vc
#
# Name
# TFP1       [Y, Y]  0.178
# TFP2       [Y, X]  0.164
# TFP3      [Y, SX]  0.135
# TFP4      [Y, SY]  0.144
# TFP5  [Y, SX, SY]  0.146
# TFP6   [Y, X, SY]  0.180

# %%
# bar plot 
# subplot 

# plot with error bars

fig = plt.figure()
#size 
fig.set_size_inches(8, 5)
# subplot padding
fig.subplots_adjust(hspace=1., wspace=0.5)
cols = ["Et [GPa]", "Eb [GPa]", "t [mm]", "b [mm]"]

for i, col in enumerate(cols):
    ax = fig.add_subplot(2, 2, i+1)
    df_old[col]["mean"].plot(kind='bar', yerr=df_old[col]["std"], capsize=5, ax=ax)
    ax.set_title(col)
    ax.set_ylabel(col)
    ax.set_xlabel("Sample")
    plt.grid()
    # rot label 45
    plt.xticks(rotation=45)

# %% [markdown]
# #### 1. Thickness Model
# $$ \Tau (t_n,t_l,n_i) = t_n + 2t_l n_i $$
# #### 2. Tensile Model
#
# $$ \mathcal{E}_t(E_n,\vec{E_l},t_n,t_l, \mathcal{C}) =
#     \frac{E_n t_n + 2t_l \  ( \vec{\delta} \cdot \vec{E_l})}{t_t} $$
# where:
# - $t_t = \Tau(t_n,t_l,n_i)$
# - $n_i$ is the number of layers.
# - $\delta = \mathcal{F}(\mathcal{C})$ is the function of the # of layers of each type.

# %% [markdown]
# #### 3. Bending Model
# $$ \mathcal{E}_b(E_n,\vec{E_l},t_n,t_l) =
# \frac{E_n I_n + 2 \  (\vec{I_l} \cdot \vec{E_l})}{I_t} $$

# %%
from AnalyticalLayers.models import Tau_model,E_flexion,E_Tensile,Fraction_Carbon

# %%
# Given tn,tl,En,El 
tn = 1.0
tl = 1.0
En = 1
El = np.array([1.0, 2.0, 3.0,4.0]) #  [ E_X , E_SX , EY , E_SY ]

# %%
# Add column to df Thickness Model Prediction 
radius = 0.29

ni = df["layers"].apply(len)
t_p = Tau_model(tn, tl, ni)
Et_p =  [E_Tensile(En, El, tn, tl, ilayer ) for ilayer in df["layers"]]
Eb_p =  [E_flexion(En, El, tn, tl, ilayer ) for ilayer in df["layers"]]
V_c = [ Fraction_Carbon(radius,tn,tl,ilayer) for ilayer in df["layers"]]
pred_df = pd.DataFrame({
    "t p [mm]"  : t_p,
    "Et p [GPa]": Et_p,
    "Eb p [GPa]": Eb_p,
    "Vc"       : V_c
})

error_df = pd.DataFrame({
    "t [mm]"  : 100*abs(df["t [mm]"]   - t_p )/df["t [mm]"]  ,
    "Et [GPa]": 100*abs(df["Et [GPa]"] - Et_p)/df["Et [GPa]"],
    "Eb [GPa]": 100*abs(df["Eb [GPa]"] - Eb_p)/df["Eb [GPa]"],
    "Vc"     : 100*abs(df["Vc"]      - V_c )/df["Vc"]
})
error_df
# Out:
#          t [mm]   Et [GPa]   Eb [GPa]         Vc
# Name
# TFP1   5.063291   9.894587  77.395738  16.878400
# TFP2   6.382979  20.301175  85.652770   9.782654
# TFP3   3.448276   9.975994  76.144012  13.887782
# TFP4   6.382979  22.380958  62.992847  19.269795
# TFP5  22.807018  66.870483  45.564611  22.443853
# TFP6  25.000000  39.583505  60.781155  24.512017

# %%
df.round(2)
# Out:
#        % e       Smax [MPa]              layers    Vc Et [GPa] Eb [GPa]  \
#       mean   std       mean    std
# Name
# TFP1  0.12  0.01     279.10  14.34       [Y, Y]  0.18     2.89    13.20
# TFP2  0.09  0.00     153.36   0.47       [Y, X]  0.16     2.26     9.87
# TFP3  0.09  0.00     137.11   5.00      [Y, SX]  0.14     2.00     9.22
# TFP4  0.10  0.01     184.40   1.36      [Y, SY]  0.14     2.45    10.18
# TFP5  0.09  0.01      99.99   9.79  [Y, SX, SY]  0.15     1.63     6.14
# TFP6  0.09  0.01     104.51   7.71   [Y, X, SY]  0.18     1.74     7.80
#
#      t [mm] b [mm]
#
# Name
# TFP1   5.27  25.60
# TFP2   4.70  25.57
# TFP3   4.83  25.40
# TFP4   4.70  25.67
# TFP5   5.70  25.17
# TFP6   5.60  25.03

# %%
theta = lambda x: 0.5 + 0.5*np.tanh(100*x)
relu  = lambda x: x*theta(x)

# %%
ni
# Out:
# Name
# TFP1    2
# TFP2    2
# TFP3    2
# TFP4    2
# TFP5    3
# TFP6    3
# Name: layers, dtype: int64

# %%
import scipy.optimize as opt
from optim.objetive import objetive
from validation.experimental import manual_data

factor={"t":1,"Et":1,"Eb":0,"Vc":1}

t_nucleo_exp = manual_data()["t_nucleo [mm]"]
def f(x):
    r  = x[0]
    tn = x[1]
    tl = x[2]
    En = x[3]
    El = x[4:]
    
    return objetive(r,tn, tl, En, El,df,ni,factor=factor)

r_0  = 3.5
nu_0 = 0.3
tn_0 = 3.0
tl_0 = 0.5
En_0 = 1.0
El_0 = [5,5,5,5]

x0 = [r_0,tn_0, tl_0, En_0, *El_0]


eps = 1e-3

tn_limits = [0.8*t_nucleo_exp,
             1.1*t_nucleo_exp]

bounds = [ 
            (0.2,0.4),  # radius
            tn_limits,  # tn
           (0.35,0.6),  # tl
           (eps,0.8),  # En
           (eps,None),  # El[0] E_X
           (eps,None),  # El[1] E_SX
           (eps,None),  # El[2] E_Y # [eps,None] or [10,30]
           (eps,None)   # El[3] E_SY
           ]  

res = opt.basinhopping(f, x0, niter=10, 
                       minimizer_kwargs={"bounds":bounds, 
                                         "method":"Nelder-Mead"})
# Out:
# c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\scipy\optimize\_basinhopping.py:294: OptimizeWarning: Initial guess is not within the specified bounds
#   return self.minimizer(self.func, x0, **self.kwargs)

# %%
print("tn in = ",tn_limits)
# Out:
# tn in =  [2.2352000000000003, 3.0734000000000004]

# %%
xopt = res.x
r_opt  = xopt[0]
tn_opt = xopt[1]
tl_opt = xopt[2]
En_opt = xopt[3]
El_opt = xopt[4:]

df_pred,error_df = objetive(r_opt,tn_opt, tl_opt, En_opt, El_opt, df,ni,give_pred=True,factor=factor)

# %%
# EX , ESX , EY , ESY

bounds_min = [ b[0] for b in bounds ]
bounds_max = [ b[1] for b in bounds ]

rows = ["r","tn", "tl", "En", "EX", "ESX", "EY", "ESY"]
units = ["mm","mm", "mm", "GPa", "GPa", "GPa", "GPa", "GPa"]
df_opt = pd.DataFrame({"Variable": rows, "x": xopt, "unit": units, "x_min": bounds_min, "x_max": bounds_max})
df_opt.index = df_opt["Variable"]
df_opt.pop("Variable")
df_opt.round(5)
# Out:
#                 x unit   x_min   x_max
# Variable
# r         0.30532   mm  0.2000  0.4000
# tn        2.32652   mm  2.2352  3.0734
# tl        0.60000   mm  0.3500  0.6000
# En        0.79771  GPa  0.0010  0.8000
# EX        1.34973  GPa  0.0010     NaN
# ESX       0.80362  GPa  0.0010     NaN
# EY        5.30644  GPa  0.0010     NaN
# ESY       1.03691  GPa  0.0010     NaN

# %%
df_opt.iloc[[5,7,4,6]].round(5)
# Out:
#                 x unit  x_min  x_max
# Variable
# ESX       0.80362  GPa  0.001    NaN
# ESY       1.03691  GPa  0.001    NaN
# EX        1.34973  GPa  0.001    NaN
# EY        5.30644  GPa  0.001    NaN

# %%
error_df.round(2)
# Out:
#       t [%]  Et [%]  Eb [%]  Vc [%]
# Name
# TFP1  10.26    6.99   63.88    2.53
# TFP2   0.56    7.79   75.12    5.79
# TFP3   2.21    2.83   76.84    0.97
# TFP4   0.56   18.28   77.68    5.34
# TFP5   3.97    8.22   74.04    1.54
# TFP6   5.83    7.53   77.48    1.17

# %%
cols = error_df.columns

fig = plt.figure()
#padding
fig.subplots_adjust(hspace=0.25, wspace=0.35)
fig.set_size_inches(7, 7)

names_title = ["Thickness", "Tensile", "Bending", "Carbon Fraction"]
# español 
names_title = ["Espesor", "Tracción", "Flexión", "Fracción de Carbono"]
for i, col in enumerate(cols):
    ax = fig.add_subplot(2, 2, i+1)
    error_df[col].plot(kind='bar', ax=ax)
    ax.set_title(col)
    ax.set_ylabel(col)
    ax.set_xlabel("Sample")
    # line 5% 
    ax.axhline(5, color='r', linestyle='--')
    # line mean 
    error_df[col].mean()
    ax.axhline(error_df[col].mean(), color='g', linestyle='--', label=r"$\mu = $"+str(round(error_df[col].mean(),2)) + "%")
    # 0,50
    plt.ylim(0,50)
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid()

    plt.xticks(np.arange(len(df.index)), 1+np.arange(len(df.index)))
    plt.xlabel("")
    plt.title(names_title[i], fontsize=10)

# %%
df
# Out:
#            % e            Smax [MPa]                  layers     Vc  Et [GPa]  \
#           mean       std        mean        std
# Name
# TFP1  0.123306  0.009827  279.103333  14.337700       [Y, Y]  0.178  2.885509
# TFP2  0.087556  0.002840  153.360000   0.473181       [Y, X]  0.164  2.258503
# TFP3  0.087444  0.002164  137.113333   4.996812      [Y, SX]  0.135  2.000437
# TFP4  0.095472  0.005491  184.396667   1.356515      [Y, SY]  0.144  2.451362
# TFP5  0.089889  0.013757   99.990000   9.790138  [Y, SX, SY]  0.146  1.626582
# TFP6  0.089083  0.010304  104.513333   7.708893   [Y, X, SY]  0.180  1.739870
#
#        Eb [GPa]    t [mm]     b [mm]
#
# Name
# TFP1  13.201050  5.266667  25.600000
# TFP2   9.869501  4.700000  25.566667
# TFP3   9.222003  4.833333  25.400000
# TFP4  10.181815  4.700000  25.666667
# TFP5   6.143105  5.700000  25.166667
# TFP6   7.798060  5.600000  25.033333

# %%
df_pred
# Out:
#         t [mm]  Et [GPa]  Eb [GPa]        Vc
# Name
# TFP1  4.726522  3.087119  4.768723  0.173492
# TFP2  4.726522  2.082566  2.455439  0.173492
# TFP3  4.726522  1.943916  2.136157  0.136315
# TFP4  4.726522  2.003145  2.272549  0.136315
# TFP5  5.926522  1.760267  1.594509  0.148246
# TFP6  5.926522  1.870843  1.756466  0.177895

# %%
# save df_pred 
df_pred.to_csv("df_pred.csv")

# %%
# plot with error bars 
fig = plt.figure()
#size
fig.set_size_inches(7, 7)

# subplot padding
fig.subplots_adjust(hspace=0.25, wspace=0.35)

cols = [ "t [mm]","Et [GPa]", "Eb [GPa]", "Vc"]

for i, col in enumerate(cols):

    names_leg = ["Experimental", "Model"]

    try:
        error = df_old[col]["std"]
        yerror = [error, np.nan*error]
    except:
        yerror = None
    # errror experimental
    
    pd.concat([ df[col], df_pred[col]], axis=1).plot(kind='bar', 
                                                     ax=fig.add_subplot(2, 2, i+1), capsize=5, yerr=yerror)
    plt.ylabel(col)
    # 45
    plt.xticks(rotation=45)
    # replace xticks by index
    plt.xticks(np.arange(len(df.index)), 1+np.arange(len(df.index)))
    plt.grid()
    # outside
    plt.legend(names_leg,loc='center left', bbox_to_anchor=(0.25, 0.15),fontsize='small')
    plt.title(names_title[i],fontsize=10)
    plt.xlabel("")

# %%
df_opt.iloc[:,:2].to_csv("df_opt.csv")
