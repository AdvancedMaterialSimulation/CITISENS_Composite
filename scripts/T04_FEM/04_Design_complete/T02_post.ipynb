# %%
import glob
import numpy as np

# %%
frds = glob.glob('output/ccx/*/*.frd')
dats = glob.glob('output/ccx/*/*.dat')

# %%
dats = dats[1:]
frds = frds[1:]

# %%
from djccx.read_dat import read_dat
from djccx.frd.readfrd import readfrd

# %%
params_composite ={
    "r"         :  0.297,
    "factor_radius": 2,
    "h"         :  0.35,
    "z0"        :  3.073/2,
    "density"   : 8,
    "interface_factor"  :  1.2,
    "with_interface"    : False,
    "mirror"            : True,
    "check_jacobian"    : False,
}

params_ccx = {
    "epsilon" : 0.1,
    "x_fixed" : True
}
params = {
    "mesh" : params_composite,
    "ccx"  : params_ccx,
}

# %%
ni = [1,2,2,2,3,3]
ni = [2,2,2,2,3,3] # Consideramos Adouble

# %%
def compute_E_eff(iffiles,ni):

    ancho = params_composite["z0"]*0.5 + ni*params_composite["h"]
    largo = 10 
    A = ancho*largo
    ifrd = readfrd(iffiles)
    df = ifrd["data"]
    Sapl = np.sum(df["F2"]*(df["y"] > df["y"].mean()))/A

    E_eff = Sapl / params["ccx"]["epsilon"]
    return E_eff

E_effs = [compute_E_eff(f,ini) for f,ini in zip(frds,ni)]
#E_effs = [compute_E_eff(f,ini) for f,ini in zip(frds[0:1],ni[0:1])]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 13
#      10     E_eff = Sapl / params["ccx"]["epsilon"]
#      11     return E_eff
# ---> 13 E_effs = [compute_E_eff(f,ini) for f,ini in zip(frds,ni)]
#      14 #E_effs = [compute_E_eff(f,ini) for f,ini in zip(frds[0:1],ni[0:1])]
#
# Cell In[7], line 6, in compute_E_eff(iffiles, ni)
#       4 largo = 10
#       5 A = ancho*largo
# ----> 6 ifrd = readfrd(iffiles)
#       7 df = ifrd["data"]
#       8 Sapl = np.sum(df["F2"]*(df["y"] > df["y"].mean()))/A
#
# File c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\frd\readfrd.py:114, in readfrd(file, remove_fail_steps, add_compute)
#     111 #mesh = mesh[:,:3]
#     112 #
#     113 out = dict()
# --> 114 out["data"] = blocks_out_list_merged[-1]
#     115 out["mesh"] = mesh
#     116 out["steps"] = name_steps_u
#
# IndexError: list index out of range

# %%
frds
# Out:
# ['output/ccx\\Adouble\\main.frd',
#  'output/ccx\\B\\main.frd',
#  'output/ccx\\C\\main.frd',
#  'output/ccx\\D\\main.frd',
#  'output/ccx\\E\\main.frd',
#  'output/ccx\\F\\main.frd']

# %%
E_effs
# Out:
# [np.float64(3555.2954821608937),
#  np.float64(2550.5783515389057),
#  np.float64(2548.049810846511),
#  np.float64(2534.7739796362393),
#  np.float64(2287.687309318334),
#  np.float64(2315.7412931177646)]

# %%
from validation.FullExperimental import FullExperimental
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = FullExperimental()
df.rename(columns={"v [X,SX,Y,SY]": "delta"}, inplace=True)

# database
# layers = df["layers"].values
# layers[0] = ["Y","Y"]
# df["layers"] = layers


df.round(3)
# Out:
#      Et [GPa]        Eb [GPa]        t [mm]         b [mm]         \
#          mean    std     mean    std   mean    std    mean    std
# Name
# TFP1    2.886  0.227   13.201  0.631  5.267  0.058  25.600  0.100
# TFP2    2.259  0.066    9.870  0.780  4.700  0.000  25.567  0.058
# TFP3    2.000  0.004    9.222  0.496  4.833  0.058  25.400  0.173
# TFP4    2.451  0.114   10.182  0.771  4.700  0.000  25.667  0.153
# TFP5    1.627  0.120    6.143  0.162  5.700  0.000  25.167  0.153
# TFP6    1.740  0.068    7.798  0.334  5.600  0.000  25.033  0.635
#
#            layers     Vc
#
# Name
# TFP1          [Y]  0.178
# TFP2       [Y, X]  0.164
# TFP3      [Y, SX]  0.135
# TFP4      [Y, SY]  0.144
# TFP5  [Y, SX, SY]  0.146
# TFP6   [Y, X, SY]  0.180

# %%
E_effs = np.array(E_effs)*1e-3
Et_exp = df["Et [GPa]"]["mean"].values

print(E_effs)
print(Et_exp)
# Out:
# [3.55529548 2.55057835 2.54804981 2.53477398 2.28768731 2.31574129]
# [2.88550922 2.25850254 2.00043656 2.45136175 1.62658228 1.73986993]

# %%
error_rel = np.abs(E_effs - Et_exp)/Et_exp

# %%
names = df.index.values

# %%
Et_exp[0:1]
# Out:
# array([2.88550922])

# %%
df_pred_analy = r"C:\Users\djoroya\Documents\GitHub\CITISENS_Composite\scripts\T03_FullOptimization\df_pred.csv"

df_pred = pd.read_csv(df_pred_analy)

# %%
Et_analitico = df_pred["Et [GPa]"].values

# %%
# bar compare 
fig, ax = plt.subplots()
width = 0.25
x = np.arange(len(E_effs))
ax.bar(x + width, Et_exp, width, label='Experimental')
ax.bar(x + 2*width, Et_analitico, width, label='Simplificado')

ax.bar(x + 3*width, E_effs, width, label='FEM')
#Et_analitico
ax.set_xticks(x)
ax.set_xticklabels(names)
plt.legend()
plt.ylabel(r"$E_{tracción} \ [GPa]$")
plt.grid()

# %%
# bar compare 
fig, ax = plt.subplots()
width = 0.25
x = np.arange(len(E_effs))
ax.bar(x + width, Et_exp, width, label='Experimental')

ax.bar(x + 2*width, E_effs, width, label='FEM')
#Et_analitico
ax.set_xticks(x)
ax.set_xticklabels(names)
plt.legend()
plt.ylabel(r"$E_{tracción} \ [GPa]$")
plt.grid()

# %%
# fem vs analitico

plt.figure()
plt.plot(Et_analitico, E_effs, 'o')
# y =x 
xlims = plt.xlim()
ylims = plt.ylim()
plt.plot([0,100],[0,100],'--',label="y=x")  

plt.xlim(1,4)
plt.ylim(1,4)

plt.xlabel(r"$E_{tracción} \ [GPa]$ (Simplificado)")
plt.ylabel(r"$E_{tracción} \ [GPa]$ (FEM)")
plt.grid()
plt.legend()

# %%
# bar compare 
fig, ax = plt.subplots()
width = 0.25
x = np.arange(len(E_effs))
ax.bar(x + width, Et_analitico, width, label='Simplificado')

ax.bar(x + 2*width, E_effs, width, label='FEM')
#Et_analitico
ax.set_xticks(x)
ax.set_xticklabels(names)
plt.legend()
plt.ylabel(r"$E_{tracción} \ [GPa]$")
plt.grid()

# %%
# plot bar error
fig, ax = plt.subplots()

ax.bar(x, 100*error_rel, width, label='Error')

ax.set_xticks(x);
ax.set_xticklabels(names)
plt.grid()
plt.ylabel(r"$\varepsilon_{rel} \ [\%]$")
# Out:
# Text(0, 0.5, '$\\varepsilon_{rel} \\ [\\%]$')

# %%
from matplotlib import pyplot as plt
import numpy as np
z0 = 3.073
zT = 4.473
Tanh = lambda z: np.tanh(z)
f = lambda z: (0.5 + 0.5*Tanh(10*(z+z0/2)))*(0.5 + 0.5*Tanh(10*(-z+z0/2)))

zpan = np.linspace(-3,3,100)

plt.figure()
plt.plot(zpan,f(zpan))
# vertical
plt.axvline(-z0/2, color='r', linestyle='--')
plt.axvline(z0/2, color='r', linestyle='--')

plt.axvline(-zT/2, color='g', linestyle='--')
plt.axvline(zT/2, color='g', linestyle='--')
