# %%
import matplotlib.pyplot as plt
import numpy as np
from functions.CreateYarnGeneral import CreateYarn
from functions.CreateComposite import CreateComposite

# %%
# !rm *.brep *.inp

# %%
# cualquier curva periodica puede ser describida por una serie de fourier




r = 5

trajs =[]  

fc1 = lambda x: np.sqrt(r**2 - x**2)
x12 = np.linspace(0,r,2000)
y12 = fc1(x12)

trajs.append( np.array([x12,y12, np.zeros_like(x12)]).T )

# =============================================================================

fc1 = lambda x: -np.sqrt(r**2 - (x-2*r)**2) + 2*r
x12 = np.linspace(r,3*r,2000)
y12 = fc1(x12)

trajs.append( np.array([x12,y12, np.zeros_like(x12)]).T )

# =============================================================================
fc1 = lambda x: np.sqrt(r**2 - (x-4*r)**2) 
x12 = np.linspace(3*r,4*r,2000)
y12 = fc1(x12)

trajs.append( np.array([x12,y12, np.zeros_like(x12)]).T )

# %%
fig = plt.figure()
fig.set_size_inches(10, 3)
# compute fourier coefficients
for itraj in trajs:

    plt.plot(itraj[:,0], itraj[:,1], 'k')

plt.axis('equal')
# Out:
# (np.float64(-1.0), np.float64(21.0), np.float64(-0.5), np.float64(10.5))

# %%
itraj
# Out:
# array([[15.        ,  0.        ,  0.        ],
#        [15.00250125,  0.15813365,  0.        ],
#        [15.0050025 ,  0.22360677,  0.        ],
#        ...,
#        [19.9949975 ,  4.9999975 ,  0.        ],
#        [19.99749875,  4.99999937,  0.        ],
#        [20.        ,  5.        ,  0.        ]])

# %%
radius = 1

first_vectors = [ [1, 0, 0] , [0, -1, 0], [0, 1, 0] ]
last_vectors  = [ [0, -1, 0], [0,  1, 0], [1, 0, 0] ]

for i,itraj in enumerate(trajs):

    file = "yarn_" + str(i) + ".brep"

    CreateYarn({"trajs": itraj, 
                "radius": radius, 
                "last_vector": last_vectors[i],
                "first_vector": first_vectors[i],
                "num_points": 20,
                "file": file})

# %%
# merge all the yarns

import gmsh

gmsh.initialize()
gmsh.model.add("composite")

for i in range(3):
    gmsh.merge("yarn_" + str(i) + ".brep")

yarns = gmsh.model.getEntities(3)
dz = 3*radius
box = gmsh.model.occ.addBox(0  , 0  , -dz/2, 
                            4*r, 2*r, dz)
# cut 
gmsh.model.occ.synchronize()

gmsh.model.occ.cut([(3, box)], yarns, removeTool=False)
# 

# the box mesh must be periodic in the x direction, y direction and z direction

gmsh.model.occ.synchronize()


# Obtener las caras de la caja cortada
box_faces = gmsh.model.getBoundary([(3, box)], oriented=False, recursive=False)


gmsh.model.occ.synchronize()


# mesh
gmsh.option.setNumber("Mesh.CharacteristicLengthMin", radius*0.1)
gmsh.option.setNumber("Mesh.CharacteristicLengthMax", 4*radius)
gmsh.option.setNumber("Mesh.MeshSizeFromCurvature", 10)
gmsh.option.setNumber("Mesh.AngleSmoothNormals", 10)
gmsh.option.setNumber("Mesh.Smoothing", 10)	
gmsh.option.setNumber("Mesh.Algorithm", 2)

gmsh.model.occ.synchronize()
gmsh.model.mesh.generate(3)
gmsh.model.mesh.setOrder(2)

# save in inp format
gmsh.write("composite_RVE.inp")
# Out:
# Info    : Reading 'yarn_0.brep'...
# Info    : Done reading 'yarn_0.brep'
# Info    : Reading 'yarn_1.brep'...
# Info    : Done reading 'yarn_1.brep'
# Info    : Reading 'yarn_2.brep'...
# Info    : Done reading 'yarn_2.brep'
# Info    : Meshing 1D...ence
# Info    : [  0%] Meshing curve 1 (Circle)
# Info    : [ 10%] Meshing curve 2 (BSpline)
# Info    : [ 10%] Meshing curve 3 (Circle)
# Info    : [ 10%] Meshing curve 4 (BSpline)
# Info    : [ 10%] Meshing curve 5 (Circle)
# Info    : [ 10%] Meshing curve 6 (BSpline)
# Info    : [ 10%] Meshing curve 7 (Circle)
# Info    : [ 10%] Meshing curve 8 (BSpline)
# Info    : [ 10%] Meshing curve 9 (Circle)
# Info    : [ 10%] Meshing curve 10 (BSpline)
# Info    : [ 10%] Meshing curve 11 (Circle)
# Info    : [ 10%] Meshing curve 12 (BSpline)
# Info    : [ 10%] Meshing curve 13 (Circle)
# Info    : [ 20%] Meshing curve 14 (BSpline)
# Info    : [ 20%] Meshing curve 15 (Circle)
# Info    : [ 20%] Meshing curve 16 (BSpline)
# Info    : [ 20%] Meshing curve 17 (Circle)
# Info    : [ 20%] Meshing curve 18 (BSpline)
# Info    : [ 20%] Meshing curve 19 (Circle)
# Info    : [ 20%] Meshing curve 20 (BSpline)
# Info    : [ 20%] Meshing curve 21 (Circle)
# Info    : [ 20%] Meshing curve 22 (BSpline)
# Info    : [ 20%] Meshing curve 23 (Circle)
# Info    : [ 20%] Meshing curve 24 (BSpline)
# Info    : [ 20%] Meshing curve 25 (Circle)
# Info    : [ 20%] Meshing curve 26 (BSpline)
# Info    : [ 30%] Meshing curve 27 (Circle)
# Info    : [ 30%] Meshing curve 28 (BSpline)
# Info    : [ 30%] Meshing curve 29 (Circle)
# Info    : [ 30%] Meshing curve 30 (BSpline)
# Info    : [ 30%] Meshing curve 31 (Circle)
# Info    : [ 30%] Meshing curve 32 (BSpline)
# Info    : [ 30%] Meshing curve 33 (Circle)
# Info    : [ 30%] Meshing curve 34 (BSpline)
# Info    : [ 30%] Meshing curve 35 (Circle)
# Info    : [ 30%] Meshing curve 36 (BSpline)
# Info    : [ 30%] Meshing curve 37 (Circle)
# Info    : [ 30%] Meshing curve 38 (BSpline)
# Info    : [ 30%] Meshing curve 39 (Circle)
# Info    : [ 40%] Meshing curve 40 (Circle)
# Info    : [ 40%] Meshing curve 41 (BSpline)
# Info    : [ 40%] Meshing curve 42 (Circle)
# Info    : [ 40%] Meshing curve 43 (BSpline)
# Info    : [ 40%] Meshing curve 44 (Circle)
# Info    : [ 40%] Meshing curve 45 (BSpline)
# Info    : [ 40%] Meshing curve 46 (Circle)
# Info    : [ 40%] Meshing curve 47 (BSpline)
# Info    : [ 40%] Meshing curve 48 (Circle)
# Info    : [ 40%] Meshing curve 49 (BSpline)
# Info    : [ 40%] Meshing curve 50 (Circle)
# Info    : [ 40%] Meshing curve 51 (BSpline)
# Info    : [ 40%] Meshing curve 52 (Circle)
# Info    : [ 50%] Meshing curve 53 (BSpline)
# Info    : [ 50%] Meshing curve 54 (Circle)
# Info    : [ 50%] Meshing curve 55 (BSpline)
# Info    : [ 50%] Meshing curve 56 (Circle)
# Info    : [ 50%] Meshing curve 57 (BSpline)
# Info    : [ 50%] Meshing curve 58 (Circle)
# Info    : [ 50%] Meshing curve 59 (BSpline)
# Info    : [ 50%] Meshing curve 60 (Circle)
# Info    : [ 50%] Meshing curve 61 (BSpline)
# Info    : [ 50%] Meshing curve 62 (Circle)
# Info    : [ 50%] Meshing curve 63 (BSpline)
# Info    : [ 50%] Meshing curve 64 (Circle)
# Info    : [ 50%] Meshing curve 65 (BSpline)
# Info    : [ 60%] Meshing curve 66 (Circle)
# Info    : [ 60%] Meshing curve 67 (BSpline)
# Info    : [ 60%] Meshing curve 68 (Circle)
# Info    : [ 60%] Meshing curve 69 (BSpline)
# Info    : [ 60%] Meshing curve 70 (Circle)
# Info    : [ 60%] Meshing curve 71 (BSpline)
# Info    : [ 60%] Meshing curve 72 (Circle)
# Info    : [ 60%] Meshing curve 73 (BSpline)
# Info    : [ 60%] Meshing curve 74 (Circle)
# Info    : [ 60%] Meshing curve 75 (BSpline)
# Info    : [ 60%] Meshing curve 76 (Circle)
# Info    : [ 60%] Meshing curve 77 (BSpline)
# Info    : [ 60%] Meshing curve 78 (Circle)
# Info    : [ 70%] Meshing curve 79 (Circle)
# Info    : [ 70%] Meshing curve 80 (BSpline)
# Info    : [ 70%] Meshing curve 81 (Circle)
# Info    : [ 70%] Meshing curve 82 (BSpline)
# Info    : [ 70%] Meshing curve 83 (Circle)
# Info    : [ 70%] Meshing curve 84 (BSpline)
# Info    : [ 70%] Meshing curve 85 (Circle)
# Info    : [ 70%] Meshing curve 86 (BSpline)
# Info    : [ 70%] Meshing curve 87 (Circle)
# Info    : [ 70%] Meshing curve 88 (BSpline)
# Info    : [ 70%] Meshing curve 89 (Circle)
# Info    : [ 70%] Meshing curve 90 (BSpline)
# Info    : [ 70%] Meshing curve 91 (Circle)
# Info    : [ 80%] Meshing curve 92 (BSpline)
# Info    : [ 80%] Meshing curve 93 (Circle)
# Info    : [ 80%] Meshing curve 94 (BSpline)
# Info    : [ 80%] Meshing curve 95 (Circle)
# Info    : [ 80%] Meshing curve 96 (BSpline)
# Info    : [ 80%] Meshing curve 97 (Circle)
# Info    : [ 80%] Meshing curve 98 (BSpline)
# Info    : [ 80%] Meshing curve 99 (Circle)
# Info    : [ 80%] Meshing curve 100 (BSpline)
# Info    : [ 80%] Meshing curve 101 (Circle)
# Info    : [ 80%] Meshing curve 102 (BSpline)
# Info    : [ 80%] Meshing curve 103 (Circle)
# Info    : [ 80%] Meshing curve 104 (BSpline)
# Info    : [ 90%] Meshing curve 105 (Circle)
# Info    : [ 90%] Meshing curve 106 (BSpline)
# Info    : [ 90%] Meshing curve 107 (Circle)
# Info    : [ 90%] Meshing curve 108 (BSpline)
# Info    : [ 90%] Meshing curve 109 (Circle)
# Info    : [ 90%] Meshing curve 110 (BSpline)
# Info    : [ 90%] Meshing curve 111 (Circle)
# Info    : [ 90%] Meshing curve 112 (BSpline)
# Info    : [ 90%] Meshing curve 113 (Circle)
# Info    : [ 90%] Meshing curve 114 (BSpline)
# Info    : [ 90%] Meshing curve 115 (Circle)
# Info    : [ 90%] Meshing curve 116 (BSpline)
# Info    : [ 90%] Meshing curve 117 (Circle)
# Info    : [100%] Meshing curve 118 (Line)
# Info    : [100%] Meshing curve 119 (Line)
# Info    : [100%] Meshing curve 120 (Line)
# Info    : [100%] Meshing curve 121 (Line)
# Info    : [100%] Meshing curve 122 (Line)
# Info    : [100%] Meshing curve 123 (Line)
# Info    : [100%] Meshing curve 124 (Line)
# Info    : [100%] Meshing curve 125 (Line)
# Info    : [100%] Meshing curve 126 (Line)
# Info    : [100%] Meshing curve 127 (Line)
# Info    : [100%] Meshing curve 128 (Line)
# Info    : [100%] Meshing curve 129 (Line)
# Info    : Done meshing 1D (Wall 0.176121s, CPU 0.177877s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (BSpline surface, MeshAdapt)
# Info    : [ 10%] Meshing surface 2 (Plane, Delaunay)
# Info    : [ 10%] Meshing surface 3 (BSpline surface, MeshAdapt)
# Info    : [ 10%] Meshing surface 4 (BSpline surface, MeshAdapt)
# Info    : [ 10%] Meshing surface 5 (BSpline surface, MeshAdapt)
# Info    : [ 10%] Meshing surface 6 (BSpline surface, MeshAdapt)
# Info    : [ 10%] Meshing surface 7 (BSpline surface, MeshAdapt)
# Info    : [ 20%] Meshing surface 8 (BSpline surface, MeshAdapt)
# Info    : [ 20%] Meshing surface 9 (BSpline surface, MeshAdapt)
# Info    : [ 20%] Meshing surface 10 (BSpline surface, MeshAdapt)
# Info    : [ 20%] Meshing surface 11 (BSpline surface, MeshAdapt)
# Info    : [ 20%] Meshing surface 12 (BSpline surface, MeshAdapt)
# Info    : [ 20%] Meshing surface 13 (BSpline surface, MeshAdapt)
# Info    : [ 20%] Meshing surface 14 (BSpline surface, MeshAdapt)
# Info    : [ 30%] Meshing surface 15 (BSpline surface, MeshAdapt)
# Info    : [ 30%] Meshing surface 16 (BSpline surface, MeshAdapt)
# Info    : [ 30%] Meshing surface 17 (BSpline surface, MeshAdapt)
# Info    : [ 30%] Meshing surface 18 (BSpline surface, MeshAdapt)
# Info    : [ 30%] Meshing surface 19 (BSpline surface, MeshAdapt)
# Info    : [ 30%] Meshing surface 20 (BSpline surface, MeshAdapt)
# Info    : [ 30%] Meshing surface 21 (Plane, Delaunay)
# Info    : [ 40%] Meshing surface 22 (BSpline surface, MeshAdapt)
# Info    : [ 40%] Meshing surface 23 (Plane, Delaunay)
# Info    : [ 40%] Meshing surface 24 (BSpline surface, MeshAdapt)
# Info    : [ 40%] Meshing surface 25 (BSpline surface, MeshAdapt)
# Info    : [ 40%] Meshing surface 26 (BSpline surface, MeshAdapt)
# Info    : [ 40%] Meshing surface 27 (BSpline surface, MeshAdapt)
# Info    : [ 40%] Meshing surface 28 (BSpline surface, MeshAdapt)
# Info    : [ 50%] Meshing surface 29 (BSpline surface, MeshAdapt)
# Info    : [ 50%] Meshing surface 30 (BSpline surface, MeshAdapt)
# Info    : [ 50%] Meshing surface 31 (BSpline surface, MeshAdapt)
# Info    : [ 50%] Meshing surface 32 (BSpline surface, MeshAdapt)
# Info    : [ 50%] Meshing surface 33 (BSpline surface, MeshAdapt)
# Info    : [ 50%] Meshing surface 34 (BSpline surface, MeshAdapt)
# Info    : [ 50%] Meshing surface 35 (BSpline surface, MeshAdapt)
# Info    : [ 60%] Meshing surface 36 (BSpline surface, MeshAdapt)
# Info    : [ 60%] Meshing surface 37 (BSpline surface, MeshAdapt)
# Info    : [ 60%] Meshing surface 38 (BSpline surface, MeshAdapt)
# Info    : [ 60%] Meshing surface 39 (BSpline surface, MeshAdapt)
# Info    : [ 60%] Meshing surface 40 (BSpline surface, MeshAdapt)
# Info    : [ 60%] Meshing surface 41 (BSpline surface, MeshAdapt)
# Info    : [ 60%] Meshing surface 42 (Plane, Delaunay)
# Info    : [ 70%] Meshing surface 43 (BSpline surface, MeshAdapt)
# Info    : [ 70%] Meshing surface 44 (Plane, Delaunay)
# Info    : [ 70%] Meshing surface 45 (BSpline surface, MeshAdapt)
# Info    : [ 70%] Meshing surface 46 (BSpline surface, MeshAdapt)
# Info    : [ 70%] Meshing surface 47 (BSpline surface, MeshAdapt)
# Info    : [ 70%] Meshing surface 48 (BSpline surface, MeshAdapt)
# Info    : [ 70%] Meshing surface 49 (BSpline surface, MeshAdapt)
# Info    : [ 80%] Meshing surface 50 (BSpline surface, MeshAdapt)
# Info    : [ 80%] Meshing surface 51 (BSpline surface, MeshAdapt)
# Info    : [ 80%] Meshing surface 52 (BSpline surface, MeshAdapt)
# Info    : [ 80%] Meshing surface 53 (BSpline surface, MeshAdapt)
# Info    : [ 80%] Meshing surface 54 (BSpline surface, MeshAdapt)
# Info    : [ 80%] Meshing surface 55 (BSpline surface, MeshAdapt)
# Info    : [ 80%] Meshing surface 56 (BSpline surface, MeshAdapt)
# Info    : [ 90%] Meshing surface 57 (BSpline surface, MeshAdapt)
# Info    : [ 90%] Meshing surface 58 (BSpline surface, MeshAdapt)
# Info    : [ 90%] Meshing surface 59 (BSpline surface, MeshAdapt)
# Info    : [ 90%] Meshing surface 60 (BSpline surface, MeshAdapt)
# Info    : [ 90%] Meshing surface 61 (BSpline surface, MeshAdapt)
# Info    : [ 90%] Meshing surface 62 (BSpline surface, MeshAdapt)
# Info    : [ 90%] Meshing surface 63 (Plane, Delaunay)
# Info    : [100%] Meshing surface 64 (Plane, Delaunay)
# Info    : [100%] Meshing surface 65 (Plane, Delaunay)
# Info    : [100%] Meshing surface 66 (Plane, Delaunay)
# Info    : [100%] Meshing surface 67 (Plane, Delaunay)
# Info    : [100%] Meshing surface 68 (Plane, Delaunay)
# Info    : [100%] Meshing surface 69 (Plane, Delaunay)
# Info    : Done meshing 2D (Wall 0.100047s, CPU 0.096656s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 4 volumes with 1 connected component
# Info    : Tetrahedrizing 1262 nodes...
# Info    : Done tetrahedrizing 1270 nodes (Wall 0.0095908s, CPU 0.0096s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.0197674s, CPU 0.019842s)
# Info    : Found volume 1
# Info    : Found volume 3
# Info    : Found volume 4
# Info    : Found volume 2
# Info    : It. 0 - 0 nodes created - worst tet radius 2.59089 (nodes removed 0 0)
# Info    : It. 500 - 196 nodes created - worst tet radius 1.09722 (nodes removed 0 304)
# Info    : 3D refinement terminated (1576 nodes total):
# Info    :  - 1 Delaunay cavities modified for star shapeness
# Info    :  - 472 nodes could not be inserted
# Info    :  - 8393 tetrahedra created in 0.0165946 sec. (505766 tets/s)
# Info    : 166 node relocations
# Info    : Done meshing 3D (Wall 0.0774434s, CPU 0.078132s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 23.4326) with worst = 0.050605 / average = 0.650632:
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :        15 elements
# Info    : 0.20 < quality < 0.30 :        13 elements
# Info    : 0.30 < quality < 0.40 :        20 elements
# Info    : 0.40 < quality < 0.50 :        72 elements
# Info    : 0.50 < quality < 0.60 :       165 elements
# Info    : 0.60 < quality < 0.70 :       273 elements
# Info    : 0.70 < quality < 0.80 :       258 elements
# Info    : 0.80 < quality < 0.90 :       106 elements
# Info    : 0.90 < quality < 1.00 :        15 elements
# Info    : 30 edge swaps, 1 node relocations (volume = 23.4326): worst = 0.259586 / average = 0.665787 (Wall 0.000338787s, CPU 0.000336s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :        22 elements
# Info    : 0.40 < quality < 0.50 :        74 elements
# Info    : 0.50 < quality < 0.60 :       166 elements
# Info    : 0.60 < quality < 0.70 :       273 elements
# Info    : 0.70 < quality < 0.80 :       252 elements
# Info    : 0.80 < quality < 0.90 :       113 elements
# Info    : 0.90 < quality < 1.00 :        16 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 47.2933) with worst = 0.0466599 / average = 0.706339:
# Info    : 0.00 < quality < 0.10 :        61 elements
# Info    : 0.10 < quality < 0.20 :        53 elements
# Info    : 0.20 < quality < 0.30 :        29 elements
# Info    : 0.30 < quality < 0.40 :        28 elements
# Info    : 0.40 < quality < 0.50 :        66 elements
# Info    : 0.50 < quality < 0.60 :       115 elements
# Info    : 0.60 < quality < 0.70 :       311 elements
# Info    : 0.70 < quality < 0.80 :       530 elements
# Info    : 0.80 < quality < 0.90 :       449 elements
# Info    : 0.90 < quality < 1.00 :       236 elements
# Info    : 134 edge swaps, 0 node relocations (volume = 47.2933): worst = 0.0588747 / average = 0.737275 (Wall 0.000784222s, CPU 0.000803s)
# Info    : 139 edge swaps, 0 node relocations (volume = 47.2933): worst = 0.0588747 / average = 0.738591 (Wall 0.000903821s, CPU 0.000931s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         4 elements
# Info    : 0.10 < quality < 0.20 :         2 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        36 elements
# Info    : 0.40 < quality < 0.50 :        64 elements
# Info    : 0.50 < quality < 0.60 :       136 elements
# Info    : 0.60 < quality < 0.70 :       394 elements
# Info    : 0.70 < quality < 0.80 :       479 elements
# Info    : 0.80 < quality < 0.90 :       423 elements
# Info    : 0.90 < quality < 1.00 :       209 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 23.4326) with worst = 0.0506022 / average = 0.655582:
# Info    : 0.00 < quality < 0.10 :         4 elements
# Info    : 0.10 < quality < 0.20 :        15 elements
# Info    : 0.20 < quality < 0.30 :        10 elements
# Info    : 0.30 < quality < 0.40 :        18 elements
# Info    : 0.40 < quality < 0.50 :        68 elements
# Info    : 0.50 < quality < 0.60 :       170 elements
# Info    : 0.60 < quality < 0.70 :       267 elements
# Info    : 0.70 < quality < 0.80 :       276 elements
# Info    : 0.80 < quality < 0.90 :       118 elements
# Info    : 0.90 < quality < 1.00 :        17 elements
# Info    : 29 edge swaps, 1 node relocations (volume = 23.4326): worst = 0.301317 / average = 0.667635 (Wall 0.000309867s, CPU 0.000324s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        24 elements
# Info    : 0.40 < quality < 0.50 :        69 elements
# Info    : 0.50 < quality < 0.60 :       172 elements
# Info    : 0.60 < quality < 0.70 :       273 elements
# Info    : 0.70 < quality < 0.80 :       267 elements
# Info    : 0.80 < quality < 0.90 :       120 elements
# Info    : 0.90 < quality < 1.00 :        17 elements
# Info    : Optimizing volume 4
# Info    : Optimization starts (volume = 505.841) with worst = 0.000775369 / average = 0.506803:
# Info    : 0.00 < quality < 0.10 :       144 elements
# Info    : 0.10 < quality < 0.20 :       438 elements
# Info    : 0.20 < quality < 0.30 :       442 elements
# Info    : 0.30 < quality < 0.40 :       489 elements
# Info    : 0.40 < quality < 0.50 :       734 elements
# Info    : 0.50 < quality < 0.60 :       702 elements
# Info    : 0.60 < quality < 0.70 :       560 elements
# Info    : 0.70 < quality < 0.80 :       528 elements
# Info    : 0.80 < quality < 0.90 :       417 elements
# Info    : 0.90 < quality < 1.00 :       158 elements
# Info    : 339 edge swaps, 36 node relocations (volume = 505.841): worst = 0.0498145 / average = 0.527117 (Wall 0.00611991s, CPU 0.006139s)
# Info    : 374 edge swaps, 44 node relocations (volume = 505.841): worst = 0.0498145 / average = 0.528803 (Wall 0.0113532s, CPU 0.011389s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :        67 elements
# Info    : 0.10 < quality < 0.20 :       313 elements
# Info    : 0.20 < quality < 0.30 :       318 elements
# Info    : 0.30 < quality < 0.40 :       525 elements
# Info    : 0.40 < quality < 0.50 :       703 elements
# Info    : 0.50 < quality < 0.60 :       690 elements
# Info    : 0.60 < quality < 0.70 :       574 elements
# Info    : 0.70 < quality < 0.80 :       536 elements
# Info    : 0.80 < quality < 0.90 :       408 elements
# Info    : 0.90 < quality < 1.00 :       152 elements
# Info    : Done optimizing mesh (Wall 0.0170759s, CPU 0.017247s)
# Info    : 1576 nodes 11460 elements
# Info    : Meshing order 2 (curvilinear on)...
# Info    : [  0%] Meshing curve 1 order 2
# Info    : [ 10%] Meshing curve 2 order 2
# Info    : [ 10%] Meshing curve 3 order 2
# Info    : [ 10%] Meshing curve 4 order 2
# Info    : [ 10%] Meshing curve 5 order 2
# Info    : [ 10%] Meshing curve 6 order 2
# Info    : [ 10%] Meshing curve 7 order 2
# Info    : [ 10%] Meshing curve 8 order 2
# Info    : [ 10%] Meshing curve 9 order 2
# Info    : [ 10%] Meshing curve 10 order 2
# Info    : [ 10%] Meshing curve 11 order 2
# Info    : [ 10%] Meshing curve 12 order 2
# Info    : [ 10%] Meshing curve 13 order 2
# Info    : [ 10%] Meshing curve 14 order 2
# Info    : [ 10%] Meshing curve 15 order 2
# Info    : [ 10%] Meshing curve 16 order 2
# Info    : [ 10%] Meshing curve 17 order 2
# Info    : [ 10%] Meshing curve 18 order 2
# Info    : [ 10%] Meshing curve 19 order 2
# Info    : [ 10%] Meshing curve 20 order 2
# Info    : [ 10%] Meshing curve 21 order 2
# Info    : [ 20%] Meshing curve 22 order 2
# Info    : [ 20%] Meshing curve 23 order 2
# Info    : [ 20%] Meshing curve 24 order 2
# Info    : [ 20%] Meshing curve 25 order 2
# Info    : [ 20%] Meshing curve 26 order 2
# Info    : [ 20%] Meshing curve 27 order 2
# Info    : [ 20%] Meshing curve 28 order 2
# Info    : [ 20%] Meshing curve 29 order 2
# Info    : [ 20%] Meshing curve 30 order 2
# Info    : [ 20%] Meshing curve 31 order 2
# Info    : [ 20%] Meshing curve 32 order 2
# Info    : [ 20%] Meshing curve 33 order 2
# Info    : [ 20%] Meshing curve 34 order 2
# Info    : [ 20%] Meshing curve 35 order 2
# Info    : [ 20%] Meshing curve 36 order 2
# Info    : [ 20%] Meshing curve 37 order 2
# Info    : [ 20%] Meshing curve 38 order 2
# Info    : [ 20%] Meshing curve 39 order 2
# Info    : [ 20%] Meshing curve 40 order 2
# Info    : [ 20%] Meshing curve 41 order 2
# Info    : [ 30%] Meshing curve 42 order 2
# Info    : [ 30%] Meshing curve 43 order 2
# Info    : [ 30%] Meshing curve 44 order 2
# Info    : [ 30%] Meshing curve 45 order 2
# Info    : [ 30%] Meshing curve 46 order 2
# Info    : [ 30%] Meshing curve 47 order 2
# Info    : [ 30%] Meshing curve 48 order 2
# Info    : [ 30%] Meshing curve 49 order 2
# Info    : [ 30%] Meshing curve 50 order 2
# Info    : [ 30%] Meshing curve 51 order 2
# Info    : [ 30%] Meshing curve 52 order 2
# Info    : [ 30%] Meshing curve 53 order 2
# Info    : [ 30%] Meshing curve 54 order 2
# Info    : [ 30%] Meshing curve 55 order 2
# Info    : [ 30%] Meshing curve 56 order 2
# Info    : [ 30%] Meshing curve 57 order 2
# Info    : [ 30%] Meshing curve 58 order 2
# Info    : [ 30%] Meshing curve 59 order 2
# Info    : [ 30%] Meshing curve 60 order 2
# Info    : [ 30%] Meshing curve 61 order 2
# Info    : [ 40%] Meshing curve 62 order 2
# Info    : [ 40%] Meshing curve 63 order 2
# Info    : [ 40%] Meshing curve 64 order 2
# Info    : [ 40%] Meshing curve 65 order 2
# Info    : [ 40%] Meshing curve 66 order 2
# Info    : [ 40%] Meshing curve 67 order 2
# Info    : [ 40%] Meshing curve 68 order 2
# Info    : [ 40%] Meshing curve 69 order 2
# Info    : [ 40%] Meshing curve 70 order 2
# Info    : [ 40%] Meshing curve 71 order 2
# Info    : [ 40%] Meshing curve 72 order 2
# Info    : [ 40%] Meshing curve 73 order 2
# Info    : [ 40%] Meshing curve 74 order 2
# Info    : [ 40%] Meshing curve 75 order 2
# Info    : [ 40%] Meshing curve 76 order 2
# Info    : [ 40%] Meshing curve 77 order 2
# Info    : [ 40%] Meshing curve 78 order 2
# Info    : [ 40%] Meshing curve 79 order 2
# Info    : [ 40%] Meshing curve 80 order 2
# Info    : [ 40%] Meshing curve 81 order 2
# Info    : [ 50%] Meshing curve 82 order 2
# Info    : [ 50%] Meshing curve 83 order 2
# Info    : [ 50%] Meshing curve 84 order 2
# Info    : [ 50%] Meshing curve 85 order 2
# Info    : [ 50%] Meshing curve 86 order 2
# Info    : [ 50%] Meshing curve 87 order 2
# Info    : [ 50%] Meshing curve 88 order 2
# Info    : [ 50%] Meshing curve 89 order 2
# Info    : [ 50%] Meshing curve 90 order 2
# Info    : [ 50%] Meshing curve 91 order 2
# Info    : [ 50%] Meshing curve 92 order 2
# Info    : [ 50%] Meshing curve 93 order 2
# Info    : [ 50%] Meshing curve 94 order 2
# Info    : [ 50%] Meshing curve 95 order 2
# Info    : [ 50%] Meshing curve 96 order 2
# Info    : [ 50%] Meshing curve 97 order 2
# Info    : [ 50%] Meshing curve 98 order 2
# Info    : [ 50%] Meshing curve 99 order 2
# Info    : [ 50%] Meshing curve 100 order 2
# Info    : [ 50%] Meshing curve 101 order 2
# Info    : [ 60%] Meshing curve 102 order 2
# Info    : [ 60%] Meshing curve 103 order 2
# Info    : [ 60%] Meshing curve 104 order 2
# Info    : [ 60%] Meshing curve 105 order 2
# Info    : [ 60%] Meshing curve 106 order 2
# Info    : [ 60%] Meshing curve 107 order 2
# Info    : [ 60%] Meshing curve 108 order 2
# Info    : [ 60%] Meshing curve 109 order 2
# Info    : [ 60%] Meshing curve 110 order 2
# Info    : [ 60%] Meshing curve 111 order 2
# Info    : [ 60%] Meshing curve 112 order 2
# Info    : [ 60%] Meshing curve 113 order 2
# Info    : [ 60%] Meshing curve 114 order 2
# Info    : [ 60%] Meshing curve 115 order 2
# Info    : [ 60%] Meshing curve 116 order 2
# Info    : [ 60%] Meshing curve 117 order 2
# Info    : [ 60%] Meshing curve 118 order 2
# Info    : [ 60%] Meshing curve 119 order 2
# Info    : [ 60%] Meshing curve 120 order 2
# Info    : [ 60%] Meshing curve 121 order 2
# Info    : [ 60%] Meshing curve 122 order 2
# Info    : [ 70%] Meshing curve 123 order 2
# Info    : [ 70%] Meshing curve 124 order 2
# Info    : [ 70%] Meshing curve 125 order 2
# Info    : [ 70%] Meshing curve 126 order 2
# Info    : [ 70%] Meshing curve 127 order 2
# Info    : [ 70%] Meshing curve 128 order 2
# Info    : [ 70%] Meshing curve 129 order 2
# Info    : [ 70%] Meshing surface 1 order 2
# Info    : [ 70%] Meshing surface 2 order 2
# Info    : [ 70%] Meshing surface 3 order 2
# Info    : [ 70%] Meshing surface 4 order 2
# Info    : [ 70%] Meshing surface 5 order 2
# Info    : [ 70%] Meshing surface 6 order 2
# Info    : [ 70%] Meshing surface 7 order 2
# Info    : [ 70%] Meshing surface 8 order 2
# Info    : [ 70%] Meshing surface 9 order 2
# Info    : [ 70%] Meshing surface 10 order 2
# Info    : [ 70%] Meshing surface 11 order 2
# Info    : [ 70%] Meshing surface 12 order 2
# Info    : [ 70%] Meshing surface 13 order 2
# Info    : [ 80%] Meshing surface 14 order 2
# Info    : [ 80%] Meshing surface 15 order 2
# Info    : [ 80%] Meshing surface 16 order 2
# Info    : [ 80%] Meshing surface 17 order 2
# Info    : [ 80%] Meshing surface 18 order 2
# Info    : [ 80%] Meshing surface 19 order 2
# Info    : [ 80%] Meshing surface 20 order 2
# Info    : [ 80%] Meshing surface 21 order 2
# Info    : [ 80%] Meshing surface 22 order 2
# Info    : [ 80%] Meshing surface 23 order 2
# Info    : [ 80%] Meshing surface 24 order 2
# Info    : [ 80%] Meshing surface 25 order 2
# Info    : [ 80%] Meshing surface 26 order 2
# Info    : [ 80%] Meshing surface 27 order 2
# Info    : [ 80%] Meshing surface 28 order 2
# Info    : [ 80%] Meshing surface 29 order 2
# Info    : [ 80%] Meshing surface 30 order 2
# Info    : [ 80%] Meshing surface 31 order 2
# Info    : [ 80%] Meshing surface 32 order 2
# Info    : [ 80%] Meshing surface 33 order 2
# Info    : [ 90%] Meshing surface 34 order 2
# Info    : [ 90%] Meshing surface 35 order 2
# Info    : [ 90%] Meshing surface 36 order 2
# Info    : [ 90%] Meshing surface 37 order 2
# Info    : [ 90%] Meshing surface 38 order 2
# Info    : [ 90%] Meshing surface 39 order 2
# Info    : [ 90%] Meshing surface 40 order 2
# Info    : [ 90%] Meshing surface 41 order 2
# Info    : [ 90%] Meshing surface 42 order 2
# Info    : [ 90%] Meshing surface 43 order 2
# Info    : [ 90%] Meshing surface 44 order 2
# Info    : [ 90%] Meshing surface 45 order 2
# Info    : [ 90%] Meshing surface 46 order 2
# Info    : [ 90%] Meshing surface 47 order 2
# Info    : [ 90%] Meshing surface 48 order 2
# Info    : [ 90%] Meshing surface 49 order 2
# Info    : [ 90%] Meshing surface 50 order 2
# Info    : [ 90%] Meshing surface 51 order 2
# Info    : [ 90%] Meshing surface 52 order 2
# Info    : [ 90%] Meshing surface 53 order 2
# Info    : [100%] Meshing surface 54 order 2
# Info    : [100%] Meshing surface 55 order 2
# Info    : [100%] Meshing surface 56 order 2
# Info    : [100%] Meshing surface 57 order 2
# Info    : [100%] Meshing surface 58 order 2
# Info    : [100%] Meshing surface 59 order 2
# Info    : [100%] Meshing surface 60 order 2
# Info    : [100%] Meshing surface 61 order 2
# Info    : [100%] Meshing surface 62 order 2
# Info    : [100%] Meshing surface 63 order 2
# Info    : [100%] Meshing surface 64 order 2
# Info    : [100%] Meshing surface 65 order 2
# Info    : [100%] Meshing surface 66 order 2
# Info    : [100%] Meshing surface 67 order 2
# Info    : [100%] Meshing surface 68 order 2
# Info    : [100%] Meshing surface 69 order 2
# Info    : [100%] Meshing volume 1 order 2
# Info    : [100%] Meshing volume 2 order 2
# Info    : [100%] Meshing volume 3 order 2
# Info    : [100%] Meshing volume 4 order 2
# Info    : Surface mesh: worst distortion = 0.00312668 (4 elements in ]0, 0.2]); worst gamma = 0.160671
# Info    : Done meshing order 2 (Wall 0.166903s, CPU 0.169026s)
# Info    : Writing 'composite_RVE.inp'...
# Info    : Done writing 'composite_RVE.inp'
# Warning : Volume mesh: worst distortion = -0.876798 (avg = 0.93581, 16 elements with jac. < 0)

# %%
from djccx.inp.inp import inp
# Out:
# Wine está instalado. Versión: wine-9.0
# Wine is installed. Calculix will be run with windows binary

# %%
inp_f = inp("composite_RVE.inp")
inp_f.remove_by_type(2)
inp_f.remove_by_type(1)

inp_f.print("composite_no_solid_RVE.inp")

# %%
young = 2960
imaterial = inp_f.CreateElasticMaterial("elastic",young,0.0)
allelset  = inp_f.CreateElsetAll()

inp_f.CreateSolidSection(allelset,imaterial)
istep = inp_f.CreateStaticStep(nlgeom=True)

# %%
import os
join = os.path.join
inflation_folder = join("output")

if not os.path.exists(inflation_folder):
    os.makedirs(inflation_folder)

# %%
frd = inp_f.run(inflation_folder)
# Out:
# Running Calculix at:  output
# Output file:  /home/djoroya/projects/CITISENS/CITISENS_Composite/scripts/RVE/output/out.txt
# Command:
#  wine /home/djoroya/projects/CITISENS/CITISENS_Composite/.conda/lib/python3.13/site-packages/djccx/bin/ccx_dynamic.exe main > out.txt
# Error reading cvf file
#
# pid:  1220959
#
# Calculix finished
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 frd = inp_f.run(inflation_folder)
#
# File ~/projects/CITISENS/CITISENS_Composite/.conda/lib/python3.13/site-packages/djccx/inp/inp.py:261, in inp.run(self, output, mkdirforce)
#     257 runccx(output,"main",**ops)
#     259 frd_file = join(output,"main.frd")
# --> 261 frd = readfrd(frd_file)
#     263 self.setResults(frd)
#     265 return frd
#
# File ~/projects/CITISENS/CITISENS_Composite/.conda/lib/python3.13/site-packages/djccx/frd/readfrd.py:114, in readfrd(file, remove_fail_steps, add_compute)
#     111 #mesh = mesh[:,:3]
#     112 #
#     113 out = dict()
# --> 114 out["data"] = blocks_out_list_merged[-1]
#     115 out["mesh"] = mesh
#     116 out["steps"] = name_steps_u
#
# IndexError: list index out of range
