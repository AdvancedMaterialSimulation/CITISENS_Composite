# %%
from Bending.FullBending import FullBending
import numpy as np
import pandas as pd

# %%
from validation.FullExperimental import FullExperimental

df_stats = FullExperimental()
# double layer
layers = df_stats["layers"].values
layers[0] = ["Y","Y"]
df_stats["layers"] = layers

# %%
# Material properties

df_layers = pd.DataFrame({ 'E': [0.880000	,   # nucleo GPa
                                 10.156513823104275	,   # X
                                 8.410846945185279		,   # SX
                                 21.993828623130256    ,   # Y
                                 8.379982151513165]}  ,   # SY
                                 index=['nucleo', 'X', 'SX', 'Y', 'SY'])

St_layers = {
    "X"   : 473.050229,   # MPa
    "SX"  : 195.889233,    # MPa
    "Y"   : 266.080492,   # MPa
    "SY"  : 93.029122,   # MPa
    "nucleo" : 0.0,
}

En = df_layers.loc["nucleo"].values[-1]*1e3

params = {
            "El": df_layers.loc[["X","SX","Y","SY"]].values.flatten(),
            "geo" : {
                        "t_n" : 2.934,
                        "t_l" : 0.475,
                        "Lx"  : 30,
                        "meshsizefactor" : 0.85,
                    },
            "sim" : {
                        "disp" : 5.0,
                        "opt": {
                                    "OMP_NUM_THREADS":4,
                                    "mpi_np":4,
                                    "mpi":True
                                },
                        "E_n":  En
                    },
            "tensile" : {
                        "disp" : 2.0,
                        "St_layers": St_layers,
                    },
        }

# %%
df_stats
# Out:
#       Et [GPa]                 % e              St [MPa]             \
#           mean       std      mean       std        mean        std
# Name
# TFP1  2.885509  0.227295  0.123306  0.009827  279.103333  14.337700
# TFP2  2.258503  0.065626  0.087556  0.002840  153.360000   0.473181
# TFP3  2.000437  0.004435  0.087444  0.002164  137.113333   4.996812
# TFP4  2.451362  0.114353  0.095472  0.005491  184.396667   1.356515
# TFP5  1.626582  0.120272  0.089889  0.013757   99.990000   9.790138
# TFP6  1.739870  0.067515  0.089083  0.010304  104.513333   7.708893
#
#        Eb [GPa]              t [mm]               b [mm]            \
#            mean       std      mean       std       mean       std
# Name
# TFP1  13.201050  0.630858  5.266667  0.057735  25.600000  0.100000
# TFP2   9.869501  0.780113  4.700000  0.000000  25.566667  0.057735
# TFP3   9.222003  0.495965  4.833333  0.057735  25.400000  0.173205
# TFP4  10.181815  0.770635  4.700000  0.000000  25.666667  0.152753
# TFP5   6.143105  0.161637  5.700000  0.000000  25.166667  0.152753
# TFP6   7.798060  0.334186  5.600000  0.000000  25.033333  0.635085
#
#         Sb [MPa]                  layers     Vc
#             mean        std
# Name
# TFP1  134.996667  18.942693       [Y, Y]  0.178
# TFP2  117.430000  15.759607       [Y, X]  0.164
# TFP3  128.053333   5.337905      [Y, SX]  0.135
# TFP4  141.703333   7.525386      [Y, SY]  0.144
# TFP5  107.433333   3.902939  [Y, SX, SY]  0.146
# TFP6  114.306667  11.800790   [Y, X, SY]  0.180

# %%
import os 
from copy import deepcopy
join = os.path.join


if not os.path.exists("output"):
    os.mkdir("output")

# %%
all_params = []

for id_design in range(6):

    params_loop = deepcopy(params)
    # =============================================================================
    params_loop["geo"]["Ly"]  = df_stats["b [mm]"]["mean"].iloc[id_design]
    
    lyrs = df_stats["layers"].iloc[id_design]
    E_l  = df_layers.loc[lyrs]["E"].values*1e3 # MPa
    params_loop["sim"]["E_l"] = E_l
    params_loop["sim"]["name_mat"] = df_stats["layers"].iloc[id_design]
    # =============================================================================
    name = df_stats.index[id_design]
    params_loop["output_folder"] = join("output", name)
    
    inp_f = FullBending(params_loop)
    
    all_params.append(params_loop)
# Out:
# Running Calculix at:  output\TFP1\sim
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP1\sim\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  4084
#
# Calculix finished
#
# ['Y', 'Y', 'nucleo', 'Y', 'Y']
# Time Step:
# Time Step:
# Time Step:
# Running Calculix at:  output\TFP1\tensile
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP1\tensile\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  20724
#
# Calculix finished
#
# ['Y', 'Y', 'nucleo', 'Y', 'Y']
# Running Calculix at:  output\TFP2\sim
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP2\sim\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  26952
#
# Calculix finished
#
# ['X', 'Y', 'nucleo', 'Y', 'X']
# Time Step:
# Time Step:
# Time Step:
# Running Calculix at:  output\TFP2\tensile
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP2\tensile\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  20456
#
# Calculix finished
#
# ['X', 'Y', 'nucleo', 'Y', 'X']
# Running Calculix at:  output\TFP3\sim
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP3\sim\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  17436
#
# Calculix finished
#
# ['SX', 'Y', 'nucleo', 'Y', 'SX']
# Time Step:
# Time Step:
# Time Step:
# Running Calculix at:  output\TFP3\tensile
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP3\tensile\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  2288
#
# Calculix finished
#
# ['SX', 'Y', 'nucleo', 'Y', 'SX']
# Running Calculix at:  output\TFP4\sim
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP4\sim\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  21936
#
# Calculix finished
#
# ['SY', 'Y', 'nucleo', 'Y', 'SY']
# Time Step:
# Time Step:
# Time Step:
# Running Calculix at:  output\TFP4\tensile
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP4\tensile\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  16848
#
# Calculix finished
#
# ['SY', 'Y', 'nucleo', 'Y', 'SY']
# Running Calculix at:  output\TFP5\sim
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP5\sim\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  12880
#
# Calculix finished
#
# ['SY', 'SX', 'Y', 'nucleo', 'Y', 'SX', 'SY']
# Time Step:
# Time Step:
# Time Step:
# Running Calculix at:  output\TFP5\tensile
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP5\tensile\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  25268
#
# Calculix finished
#
# ['SY', 'SX', 'Y', 'nucleo', 'Y', 'SX', 'SY']
# Running Calculix at:  output\TFP6\sim
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP6\sim\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  2908
#
# Calculix finished
#
# ['SY', 'X', 'Y', 'nucleo', 'Y', 'X', 'SY']
# Time Step:
# Time Step:
# Time Step:
# Running Calculix at:  output\TFP6\tensile
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts\T02_Modelo_MultiCapa\T02_NumericalModelNOPBC\output\TFP6\tensile\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 4 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  21808
#
# Calculix finished
#
# ['SY', 'X', 'Y', 'nucleo', 'Y', 'X', 'SY']

# %%
df_stats["Eb pred [GPa]"]  = [ iall_params["Eflex"] for iall_params in all_params]
df_stats["Et pred [GPa]"]  = [ iall_params["Etensile"] for iall_params in all_params]
df_stats["Eb analytical pred [GPa]"]  = [ iall_params["Eflexion_analytical"] for iall_params in all_params]
df_stats["Et analytical pred [GPa]"]  = [ iall_params["Etensile_analytical"] for iall_params in all_params]
df_stats["St pred [MPa]"] = [ iall_params["rpost"]["S_prediction"] for iall_params in all_params]
df_stats["Sb pred [MPa]"] = [ iall_params["rpostbending"] for iall_params in all_params]

df_stats["St analytical pred [MPa]"] = [ 1e3*iall_params["St_analytical"] for iall_params in all_params]
df_stats["Sb analytical pred [MPa]"] = [ iall_params["Sb_analytical"] for iall_params in all_params]

tau_pred  = [ iall_params["geo"]["t_t"] for iall_params in all_params]
df_stats["t pred [mm]"] = tau_pred

# %%
df_stats.columns
# Out:
# MultiIndex([(                'Et [GPa]', 'mean'),
#             (                'Et [GPa]',  'std'),
#             (                     '% e', 'mean'),
#             (                     '% e',  'std'),
#             (                'St [MPa]', 'mean'),
#             (                'St [MPa]',  'std'),
#             (                'Eb [GPa]', 'mean'),
#             (                'Eb [GPa]',  'std'),
#             (                  't [mm]', 'mean'),
#             (                  't [mm]',  'std'),
#             (                  'b [mm]', 'mean'),
#             (                  'b [mm]',  'std'),
#             (                'Sb [MPa]', 'mean'),
#             (                'Sb [MPa]',  'std'),
#             (                  'layers',     ''),
#             (                      'Vc',     ''),
#             (           'Eb pred [GPa]',     ''),
#             (           'Et pred [GPa]',     ''),
#             ('Eb analytical pred [GPa]',     ''),
#             ('Et analytical pred [GPa]',     ''),
#             (           'St pred [MPa]',     ''),
#             (           'Sb pred [MPa]',     ''),
#             ('St analytical pred [MPa]',     ''),
#             ('Sb analytical pred [MPa]',     ''),
#             (             't pred [mm]',     '')],
#            )

# %%
from matplotlib import pyplot as plt

# %%
# plot bars with error bars Espesor (mm)
width = 0.3
idx = df_stats.index
idx_range = np.arange(len(idx))

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(131)

plt.bar(idx_range+width , 
        df_stats['t [mm]']['mean'], 
        yerr  = df_stats['t [mm]']['std'], 
        label ='Experimental',
        width = width)

plt.bar(idx_range, tau_pred, 
        label='Predicted', 
        alpha=0.5, 
        width=width)
plt.title('Espesor (mm)')

plt.legend()
plt.xticks(rotation=45)
plt.xlabel('') 
plt.grid()
plt.xticks(idx_range, idx);

ax = fig.add_subplot(132)

# plot bars with error bars Modulo Tracción [MPa] and prediction

plt.bar(idx_range+width , 
        df_stats['Eb [GPa]']['mean'], 
        yerr  = df_stats['Eb [GPa]']['std'], 
        label = 'Experimental',
        width = width)

plt.bar(idx_range, df_stats['Eb pred [GPa]'], 
        label='Predicted', 
        alpha=0.5, 
        width=width)
plt.legend()
plt.grid()
# off xlabel
plt.xlabel('') 
plt.xticks(rotation=45)
# tick labels 
plt.xticks(idx_range, idx);

plt.title('Modulo Flexión [GPa]')

ax = fig.add_subplot(133)

# plot bars with error bars St [MPa] and prediction
Et_exp = df_stats["Et [GPa]"]["mean"]
Et_exp_err = df_stats["Et [GPa]"]["std"]

plt.bar(idx_range+width ,
         Et_exp, 
         yerr=Et_exp_err, label='Experimental',width=width)
plt.bar(idx_range, df_stats['Et pred [GPa]'], label='Predicted', alpha=0.5, width=width)
plt.legend()
plt.grid()
# off xlabel
plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Modulo Tracción [GPa]')
# Out:
# Text(0.5, 1.0, 'Modulo Tracción [GPa]')

# %%
df_stats
# Out:
#       Et [GPa]                 % e              St [MPa]             \
#           mean       std      mean       std        mean        std
# Name
# TFP1  2.885509  0.227295  0.123306  0.009827  279.103333  14.337700
# TFP2  2.258503  0.065626  0.087556  0.002840  153.360000   0.473181
# TFP3  2.000437  0.004435  0.087444  0.002164  137.113333   4.996812
# TFP4  2.451362  0.114353  0.095472  0.005491  184.396667   1.356515
# TFP5  1.626582  0.120272  0.089889  0.013757   99.990000   9.790138
# TFP6  1.739870  0.067515  0.089083  0.010304  104.513333   7.708893
#
#        Eb [GPa]              t [mm]            ...     Vc Eb pred [GPa]  \
#            mean       std      mean       std  ...
# Name                                           ...
# TFP1  13.201050  0.630858  5.266667  0.057735  ...  0.178     13.262829
# TFP2   9.869501  0.780113  4.700000  0.000000  ...  0.164      9.496763
# TFP3   9.222003  0.495965  4.833333  0.057735  ...  0.135      8.893556
# TFP4  10.181815  0.770635  4.700000  0.000000  ...  0.144      8.884321
# TFP5   6.143105  0.161637  5.700000  0.000000  ...  0.146      7.733915
# TFP6   7.798060  0.334186  5.600000  0.000000  ...  0.180      8.046092
#
#      Et pred [GPa] Eb analytical pred [GPa] Et analytical pred [GPa]  \
#
# Name
# TFP1     10.086570                13.818320                 9.178774
# TFP2      7.530164                 9.260497                 6.852450
# TFP3      7.153167                 8.588348                 6.509384
# TFP4      7.146506                 8.576464                 6.503318
# TFP5      7.490794                 7.804003                 6.816623
# TFP6      7.805871                 8.196378                 7.103342
#
#      St pred [MPa] Sb pred [MPa] St analytical pred [MPa]  \
#
# Name
# TFP1    111.045476    171.902537               111.044457
# TFP2     82.901472    167.059639                82.900681
# TFP3     78.750841    153.548287                78.750276
# TFP4     72.196412     97.391399                72.195617
# TFP5     75.674433     88.928398                75.673719
# TFP6     78.857536     92.893175                78.856688
#
#      Sb analytical pred [MPa] t pred [mm]
#
# Name
# TFP1                 0.167174       4.834
# TFP2                 0.139436       4.834
# TFP3                 0.129315       4.834
# TFP4                 0.095210       4.834
# TFP5                 0.086635       5.784
# TFP6                 0.090991       5.784
#
# [6 rows x 25 columns]

# %%
# plot bars with error bars Espesor (mm)
width = 0.3
idx = df_stats.index
idx_range = np.arange(len(idx))

fig = plt.figure(figsize=(9, 9))
# subplot 
fig.subplots_adjust(hspace=0.35, wspace=0.35)

ax = fig.add_subplot(222)

# plot bars with error bars Modulo Flexion [GPa] and prediction

plt.bar(idx_range+width , df_stats['Eb [GPa]']['mean'], yerr=df_stats['Eb [GPa]']['std'], label='Experimental',width=width)
plt.bar(idx_range, df_stats['Eb pred [GPa]'], label='FEM', alpha=0.5, width=width)

Eb_pred_1   = df_stats['Eb pred [GPa]'].values[0]
Eb_analytical_1 = df_stats['Eb analytical pred [GPa]'].values[0]
# factor = Eb_pred_1/Eb_analytical_1
# plt.bar(idx_range-width, factor*df_stats['Eb analytical pred [GPa]'], label='Analytical', alpha=0.5, width=width)

plt.bar(idx_range-width, df_stats['Eb analytical pred [GPa]'], label='Analytical', alpha=0.5, width=width)

plt.legend()
plt.grid()
# off xlabel
plt.xlabel('') 
plt.xticks(rotation=45)
# tick labels 
plt.xticks(idx_range, idx);

plt.title('Modulo Flexión [GPa]')

ax = fig.add_subplot(221)

# plot bars with error bars Modulo Tracción [MPa] and prediction
Et_exp = df_stats["Et [GPa]"]["mean"]
Et_exp_err = df_stats["Et [GPa]"]["std"]

plt.bar(idx_range+width , Et_exp, yerr=Et_exp_err, label='Experimental',width=width)
plt.bar(idx_range, df_stats['Et pred [GPa]'], label='FEM', alpha=0.5, width=width)
plt.bar(idx_range-width, df_stats['Et analytical pred [GPa]'], label='Analytical', alpha=0.5, width=width)
plt.legend()
plt.grid()
# off xlabel
plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Modulo Tracción [GPa]')


ax = fig.add_subplot(223)

# 
St_exp = df_stats["St [MPa]"]["mean"]
St_exp_err = df_stats["St [MPa]"]["std"]

plt.bar(idx_range+width , St_exp, yerr=St_exp_err, label='Experimental',width=width)
plt.bar(idx_range, df_stats['St pred [MPa]'], label='FEM', alpha=0.5, width=width)
plt.bar(idx_range-width, df_stats['St analytical pred [MPa]'], label='Analytical', alpha=0.5, width=width)

plt.legend()
plt.grid()
# off xlabel

plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Tensión máxima Tracción  [MPa]')
# ========================
ax = fig.add_subplot(224)

Sb_exp = df_stats["Sb [MPa]"]["mean"]
Sb_exp_err = df_stats["Sb [MPa]"]["std"]

plt.bar(idx_range+width , Sb_exp, yerr=Sb_exp_err, label='Experimental',width=width)
plt.bar(idx_range, df_stats['Sb pred [MPa]'], label='FEM', alpha=0.5, width=width)
plt.bar(idx_range-width, 1e3*df_stats['Sb analytical pred [MPa]'], label='Analytical', alpha=0.5, width=width)

plt.title('Tensión máxima Flexión [MPa]')
plt.xlabel('')
plt.xticks(rotation=45)
plt.xticks(idx_range, idx);
plt.legend()
plt.grid()

# %%
# plot bars with error bars Modulo Tracción [MPa] and prediction

plt.subplot(1, 2, 1)
Et_exp = df_stats["Et [GPa]"]["mean"]
Et_exp_err = df_stats["Et [GPa]"]["std"]

plt.bar(idx_range+width , Et_exp, yerr=Et_exp_err, label='Experimental',width=width)
plt.bar(idx_range, df_stats['Et pred [GPa]'], label='FEM', alpha=0.5, width=width)
plt.bar(idx_range-width, 1.1*df_stats['Et analytical pred [GPa]'], label='Analytical', alpha=0.5, width=width)
plt.legend()
plt.grid()
# off xlabel
plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Modulo Tracción [GPa]')

plt.subplot(1, 2, 2)
#vs plot 
plt.plot(1.1*df_stats['Et analytical pred [GPa]'], df_stats['Et pred [GPa]'], 'o', label='FEM vs Analytical')
# 1:1 line
xmin = min(df_stats['Et analytical pred [GPa]'].min(), df_stats['Et pred [GPa]'].min())
xmax = max(df_stats['Et analytical pred [GPa]'].max(), df_stats['Et pred [GPa]'].max())
plt.plot([xmin, xmax], [xmin, xmax], 'k--', label='1:1 line')

# %%
# plot bars with error bars Espesor (mm)
width = 0.3
idx = df_stats.index
idx_range = np.arange(len(idx))

fig = plt.figure(figsize=(9, 7))
# subplot 
fig.subplots_adjust(hspace=0.35, wspace=0.35)

ax = fig.add_subplot(222)

# plot bars with error bars Modulo Flexion [GPa] and prediction

plt.bar(idx_range, df_stats['Eb pred [GPa]'], label='FEM', width=width)

Eb_pred_1   = df_stats['Eb pred [GPa]'].values[0]
Eb_analytical_1 = df_stats['Eb analytical pred [GPa]'].values[0]

plt.bar(idx_range-width, df_stats['Eb analytical pred [GPa]'], label='Analítico', width=width)

plt.legend()
plt.grid()
# off xlabel
plt.xlabel('') 
plt.xticks(rotation=45)
# tick labels 
plt.xticks(idx_range, idx);

plt.title('Modulo Flexión [GPa]')

ax = fig.add_subplot(221)

# plot bars with error bars Modulo Tracción [MPa] and prediction
Et_exp = df_stats["Et [GPa]"]["mean"]
Et_exp_err = df_stats["Et [GPa]"]["std"]

plt.bar(idx_range, df_stats['Et pred [GPa]'], label='FEM', width=width)
plt.bar(idx_range-width, df_stats['Et analytical pred [GPa]'], label='Analítico',  width=width)
plt.legend()
plt.grid()
# off xlabel
plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Modulo Tracción [GPa]')


ax = fig.add_subplot(223)

# 
St_exp = df_stats["St [MPa]"]["mean"]
St_exp_err = df_stats["St [MPa]"]["std"]

plt.bar(idx_range, df_stats['St pred [MPa]'], label='FEM', width=width)
plt.bar(idx_range-width, df_stats['St analytical pred [MPa]'], label='Analítico', width=width)

plt.legend()
plt.grid()
# off xlabel

plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Tensión máxima Tracción  [MPa]')
# ========================
ax = fig.add_subplot(224)

Sb_exp = df_stats["Sb [MPa]"]["mean"]
Sb_exp_err = df_stats["Sb [MPa]"]["std"]

plt.bar(idx_range, df_stats['Sb pred [MPa]'], label='FEM', width=width)
plt.bar(idx_range-width, 1e3*df_stats['Sb analytical pred [MPa]'], label='Analítico', width=width)

plt.title('Tensión máxima Flexión [MPa]')
plt.xlabel('')
plt.xticks(rotation=45)
plt.xticks(idx_range, idx);
plt.legend()
plt.grid()

# %%
df_stats['Sb analytical pred [MPa]']*1e3
# Out:
# Name
# TFP1    167.173509
# TFP2    139.435687
# TFP3    129.315110
# TFP4     95.210338
# TFP5     86.634977
# TFP6     90.990864
# Name: Sb analytical pred [MPa], dtype: float64

# %%
Et_exp
# Out:
# Name
# TFP1    2.885509
# TFP2    2.258503
# TFP3    2.000437
# TFP4    2.451362
# TFP5    1.626582
# TFP6    1.739870
# Name: mean, dtype: float64

# %%
df_stats
# Out:
#       Et [GPa]                 % e              St [MPa]             \
#           mean       std      mean       std        mean        std
# Name
# TFP1  2.885509  0.227295  0.123306  0.009827  279.103333  14.337700
# TFP2  2.258503  0.065626  0.087556  0.002840  153.360000   0.473181
# TFP3  2.000437  0.004435  0.087444  0.002164  137.113333   4.996812
# TFP4  2.451362  0.114353  0.095472  0.005491  184.396667   1.356515
# TFP5  1.626582  0.120272  0.089889  0.013757   99.990000   9.790138
# TFP6  1.739870  0.067515  0.089083  0.010304  104.513333   7.708893
#
#        Eb [GPa]              t [mm]            ...     Vc Eb pred [GPa]  \
#            mean       std      mean       std  ...
# Name                                           ...
# TFP1  13.201050  0.630858  5.266667  0.057735  ...  0.178     13.262829
# TFP2   9.869501  0.780113  4.700000  0.000000  ...  0.164      9.496763
# TFP3   9.222003  0.495965  4.833333  0.057735  ...  0.135      8.893556
# TFP4  10.181815  0.770635  4.700000  0.000000  ...  0.144      8.884321
# TFP5   6.143105  0.161637  5.700000  0.000000  ...  0.146      7.733915
# TFP6   7.798060  0.334186  5.600000  0.000000  ...  0.180      8.046092
#
#      Et pred [GPa] Eb analytical pred [GPa] Et analytical pred [GPa]  \
#
# Name
# TFP1     10.086570                13.818320                 9.178774
# TFP2      7.530164                 9.260497                 6.852450
# TFP3      7.153167                 8.588348                 6.509384
# TFP4      7.146506                 8.576464                 6.503318
# TFP5      7.490794                 7.804003                 6.816623
# TFP6      7.805871                 8.196378                 7.103342
#
#      St pred [MPa] Sb pred [MPa] St analytical pred [MPa]  \
#
# Name
# TFP1    111.045476    171.902537               111.044457
# TFP2     82.901472    167.059639                82.900681
# TFP3     78.750841    153.548287                78.750276
# TFP4     72.196412     97.391399                72.195617
# TFP5     75.674433     88.928398                75.673719
# TFP6     78.857536     92.893175                78.856688
#
#      Sb analytical pred [MPa] t pred [mm]
#
# Name
# TFP1                 0.167174       4.834
# TFP2                 0.139436       4.834
# TFP3                 0.129315       4.834
# TFP4                 0.095210       4.834
# TFP5                 0.086635       5.784
# TFP6                 0.090991       5.784
#
# [6 rows x 25 columns]

# %%
df_save = pd.DataFrame({"Eb [GPa]"        : df_stats['Eb [GPa]']['mean'].values,
                        "Eb pred [GPa]"   : df_stats['Eb pred [GPa]'].values,
                        "Et [GPa]"        : df_stats["Et [GPa]"]["mean"].values,
                        "Et pred [GPa]"   : df_stats['Et pred [GPa]'].values,
                        "Name": df_stats.index})

df_save.to_csv("output.csv", index=False)

# %%
plt.plot(df_stats["Eb analytical pred [GPa]"],df_stats["Eb pred [GPa]"],'o')
plt.plot([0,15],[0,15],'r--')
plt.grid()
plt.ylabel("FEM")
plt.xlabel("Analytical")
plt.title("Modulo Flexión [GPa]")

for i in range(len(df_stats)):
    plt.text(df_stats["Eb analytical pred [GPa]"].iloc[i],
             df_stats["Eb pred [GPa]"].iloc[i],
             df_stats.index[i])
plt.xlim(0,25)
plt.ylim(0,25)
# Out:
# (0.0, 25.0)

# %%
params
# Out:
# {'El': array([10.15651382,  8.41084695, 21.99382862,  8.37998215]),
#  'geo': {'t_n': 2.934, 't_l': 0.475, 'Lx': 30, 'meshsizefactor': 0.85},
#  'sim': {'disp': 5.0,
#   'opt': {'OMP_NUM_THREADS': 4, 'mpi_np': 4, 'mpi': True},
#   'E_n': np.float64(880.0)},
#  'tensile': {'disp': 2.0,
#   'St_layers': {'X': 473.050229,
#    'SX': 195.889233,
#    'Y': 266.080492,
#    'SY': 93.029122,
#    'nucleo': 0.0}}}

# %%
El = df_layers.loc["Y"].values
En = df_layers.loc["nucleo"].values
tn = params["geo"]["t_n"]
tl = params["geo"]["t_l"]

# %%
print("El", El)
print("En", En)
print("tn", tn)
print("tl", tl)
# Out:
# El [21.99382862]
# En [0.88]
# tn 2.934
# tl 0.475

# %%
E_eff = (En*tn + 2*(2*El*tl)) / (tn + 2*(2*tl))
print(E_eff)
# Out:
# [9.17877418]

# %%
Forces = [ iall["Force"] for iall in all_params]

# %%
Forces
# Out:
# [np.float64(3551.1769602031986),
#  np.float64(2539.4863603873546),
#  np.float64(2362.6823399944014),
#  np.float64(2385.0083601383108),
#  np.float64(3487.2749410318866),
#  np.float64(3608.8162601877984)]

# %%
# Save Force to csv
df_force = pd.DataFrame(Forces)
df_force.columns = ["Force"]
df_force.to_csv("output_force.csv", index=False)

# %%
df_force
# Out:
#          Force
# 0  3551.176960
# 1  2539.486360
# 2  2362.682340
# 3  2385.008360
# 4  3487.274941
# 5  3608.816260
