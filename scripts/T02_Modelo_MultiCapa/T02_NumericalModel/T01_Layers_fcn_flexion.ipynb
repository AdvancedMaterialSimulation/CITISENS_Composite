# %%
from Bending.FullBending import FullBending
import numpy as np
import pandas as pd
# Out:
# Wine está instalado. Versión: wine-9.0
# Wine is installed. Calculix will be run with windows binary
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified

# %%
from validation.FullExperimental import FullExperimental

df_stats = FullExperimental()
# double layer
layers = df_stats["layers"].values
layers[0] = ["Y","Y"]
df_stats["layers"] = layers

# %%
# Material properties

df_layers = pd.DataFrame({ 'E': [0.800000	,   # nucleo GPa
                                 5.198613	,   # X
                                 2.814443		,   # SX
                                 21.284290    ,   # Y
                                 5.775806]}  ,   # SY
                                 index=['nucleo', 'X', 'SX', 'Y', 'SY'])

St_layers = {
    "X"   : 481.083731,   # MPa
    "SX"  : 80.120493,    # MPa
    "Y"   : 667.663085,   # MPa
    "SY"  : 127.036236,   # MPa
    "nucleo" : 0.0,
}

En = df_layers.loc["nucleo"].values[-1]*1e3

params = {
            "El": df_layers.loc[["X","SX","Y","SY"]].values.flatten(),
            "geo" : {
                        "t_n" : 2.934,
                        "t_l" : 0.475,
                        "Lx"  : 30,
                        "meshsizefactor" : 0.85,
                    },
            "sim" : {
                        "disp" : 5.0,
                        "opt": {
                                    "OMP_NUM_THREADS":4,
                                    "mpi_np":4,
                                    "mpi":True
                                },
                        "E_n":  En
                    },
            "tensile" : {
                        "disp" : 3.0,
                        "St_layers": St_layers,
                    },
        }

# %%
df_stats
# Out:
#       Et [GPa]                 % e              St [MPa]             \
#           mean       std      mean       std        mean        std
# Name
# TFP1  2.885509  0.227295  0.123306  0.009827  279.103333  14.337700
# TFP2  2.258503  0.065626  0.087556  0.002840  153.360000   0.473181
# TFP3  2.000437  0.004435  0.087444  0.002164  137.113333   4.996812
# TFP4  2.451362  0.114353  0.095472  0.005491  184.396667   1.356515
# TFP5  1.626582  0.120272  0.089889  0.013757   99.990000   9.790138
# TFP6  1.739870  0.067515  0.089083  0.010304  104.513333   7.708893
#
#        Eb [GPa]              t [mm]               b [mm]            \
#            mean       std      mean       std       mean       std
# Name
# TFP1  13.201050  0.630858  5.266667  0.057735  25.600000  0.100000
# TFP2   9.869501  0.780113  4.700000  0.000000  25.566667  0.057735
# TFP3   9.222003  0.495965  4.833333  0.057735  25.400000  0.173205
# TFP4  10.181815  0.770635  4.700000  0.000000  25.666667  0.152753
# TFP5   6.143105  0.161637  5.700000  0.000000  25.166667  0.152753
# TFP6   7.798060  0.334186  5.600000  0.000000  25.033333  0.635085
#
#         Sb [MPa]                  layers     Vc
#             mean        std
# Name
# TFP1  134.996667  18.942693       [Y, Y]  0.178
# TFP2  117.430000  15.759607       [Y, X]  0.164
# TFP3  128.053333   5.337905      [Y, SX]  0.135
# TFP4  141.703333   7.525386      [Y, SY]  0.144
# TFP5  107.433333   3.902939  [Y, SX, SY]  0.146
# TFP6  114.306667  11.800790   [Y, X, SY]  0.180

# %%
import os 
from copy import deepcopy
join = os.path.join


if not os.path.exists("output"):
    os.mkdir("output")

# %%
all_params = []

for id_design in range(6):

    params_loop = deepcopy(params)
    # =============================================================================
    params_loop["geo"]["Ly"]  = df_stats["b [mm]"]["mean"].iloc[id_design]
    
    lyrs = df_stats["layers"].iloc[id_design]
    E_l  = df_layers.loc[lyrs]["E"].values*1e3 # MPa
    params_loop["sim"]["E_l"] = E_l
    params_loop["sim"]["name_mat"] = df_stats["layers"].iloc[id_design]
    # =============================================================================
    name = df_stats.index[id_design]
    params_loop["output_folder"] = join("output", name)
    
    inp_f = FullBending(params_loop)
    
    all_params.append(params_loop)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 13 (Line)
# Info    : [ 10%] Meshing curve 14 (Line)
# Info    : [ 10%] Meshing curve 15 (Line)
# Info    : [ 10%] Meshing curve 16 (Line)
# Info    : [ 10%] Meshing curve 17 (Line)
# Info    : [ 20%] Meshing curve 18 (Line)
# Info    : [ 20%] Meshing curve 19 (Line)
# Info    : [ 20%] Meshing curve 20 (Line)
# Info    : [ 20%] Meshing curve 21 (Line)
# Info    : [ 30%] Meshing curve 22 (Line)
# Info    : [ 30%] Meshing curve 23 (Line)
# Info    : [ 30%] Meshing curve 24 (Line)
# Info    : [ 30%] Meshing curve 25 (Line)
# Info    : [ 30%] Meshing curve 26 (Line)
# Info    : [ 40%] Meshing curve 27 (Line)
# Info    : [ 40%] Meshing curve 28 (Line)
# Info    : [ 40%] Meshing curve 29 (Line)
# Info    : [ 40%] Meshing curve 30 (Line)
# Info    : [ 50%] Meshing curve 31 (Line)
# Info    : [ 50%] Meshing curve 32 (Line)
# Info    : [ 50%] Meshing curve 33 (Line)
# Info    : [ 50%] Meshing curve 34 (Line)
# Info    : [ 60%] Meshing curve 35 (Line)
# Info    : [ 60%] Meshing curve 36 (Line)
# Info    : [ 60%] Meshing curve 37 (Line)
# Info    : [ 60%] Meshing curve 38 (Line)
# Info    : [ 60%] Meshing curve 39 (Line)
# Info    : [ 70%] Meshing curve 40 (Line)
# Info    : [ 70%] Meshing curve 41 (Line)
# Info    : [ 70%] Meshing curve 42 (Line)
# Info    : [ 70%] Meshing curve 43 (Line)
# Info    : [ 80%] Meshing curve 44 (Line)
# Info    : [ 80%] Meshing curve 45 (Line)
# Info    : [ 80%] Meshing curve 46 (Line)
# Info    : [ 80%] Meshing curve 47 (Line)
# Info    : [ 80%] Meshing curve 48 (Line)
# Info    : [ 90%] Meshing curve 49 (Line)
# Info    : [ 90%] Meshing curve 50 (Line)
# Info    : [ 90%] Meshing curve 51 (Line)
# Info    : [ 90%] Meshing curve 52 (Line)
# Info    : [100%] Meshing curve 53 (Line)
# Info    : [100%] Meshing curve 54 (Line)
# Info    : [100%] Meshing curve 55 (Line)
# Info    : [100%] Meshing curve 56 (Line)
# Info    : Done meshing 1D (Wall 0.0208362s, CPU 0.021176s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 7 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 8 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 9 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 10 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 13 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 14 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 15 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 16 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 17 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 18 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 19 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 20 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 21 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 22 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 23 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 24 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 25 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 26 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 27 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 28 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 29 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 30 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 31 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 32 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.037404s, CPU 0.037854s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 5 volumes with 1 connected component
# Info    : Tetrahedrizing 2194 nodes...
# Info    : Done tetrahedrizing 2202 nodes (Wall 0.0208058s, CPU 0.020774s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 34 Steiner points
# Info    : Done reconstructing mesh (Wall 0.0723744s, CPU 0.069092s)
# Info    : Found volume 3
# Info    : Found volume 4
# Info    : Found volume 1
# Info    : Found volume 2
# Info    : Found volume 5
# Info    : It. 0 - 0 nodes created - worst tet radius 4.60876 (nodes removed 0 0)
# Info    : 3D refinement terminated (2342 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 56 nodes could not be inserted
# Info    :  - 10263 tetrahedra created in 0.00553528 sec. (1854106 tets/s)
# Info    : 46 node relocations
# Info    : Done meshing 3D (Wall 0.119775s, CPU 0.11606s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 364.8) with worst = 0.0886863 / average = 0.51978:
# Info    : 0.00 < quality < 0.10 :        12 elements
# Info    : 0.10 < quality < 0.20 :        15 elements
# Info    : 0.20 < quality < 0.30 :        15 elements
# Info    : 0.30 < quality < 0.40 :        94 elements
# Info    : 0.40 < quality < 0.50 :       960 elements
# Info    : 0.50 < quality < 0.60 :       305 elements
# Info    : 0.60 < quality < 0.70 :       168 elements
# Info    : 0.70 < quality < 0.80 :       200 elements
# Info    : 0.80 < quality < 0.90 :        63 elements
# Info    : 0.90 < quality < 1.00 :        21 elements
# Info    : 6 edge swaps, 10 node relocations (volume = 364.8): worst = 0.0886863 / average = 0.520672 (Wall 0.000363718s, CPU 0.000404s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :        12 elements
# Info    : 0.10 < quality < 0.20 :        12 elements
# Info    : 0.20 < quality < 0.30 :        13 elements
# Info    : 0.30 < quality < 0.40 :        94 elements
# Info    : 0.40 < quality < 0.50 :       961 elements
# Info    : 0.50 < quality < 0.60 :       307 elements
# Info    : 0.60 < quality < 0.70 :       168 elements
# Info    : 0.70 < quality < 0.80 :       200 elements
# Info    : 0.80 < quality < 0.90 :        62 elements
# Info    : 0.90 < quality < 1.00 :        22 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 364.8) with worst = 0.0948182 / average = 0.524216:
# Info    : 0.00 < quality < 0.10 :         4 elements
# Info    : 0.10 < quality < 0.20 :        16 elements
# Info    : 0.20 < quality < 0.30 :        11 elements
# Info    : 0.30 < quality < 0.40 :        70 elements
# Info    : 0.40 < quality < 0.50 :       967 elements
# Info    : 0.50 < quality < 0.60 :       303 elements
# Info    : 0.60 < quality < 0.70 :       177 elements
# Info    : 0.70 < quality < 0.80 :       196 elements
# Info    : 0.80 < quality < 0.90 :        64 elements
# Info    : 0.90 < quality < 1.00 :        21 elements
# Info    : 5 edge swaps, 4 node relocations (volume = 364.8): worst = 0.0948182 / average = 0.525214 (Wall 0.000296738s, CPU 0.00032s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         4 elements
# Info    : 0.10 < quality < 0.20 :        12 elements
# Info    : 0.20 < quality < 0.30 :        10 elements
# Info    : 0.30 < quality < 0.40 :        71 elements
# Info    : 0.40 < quality < 0.50 :       966 elements
# Info    : 0.50 < quality < 0.60 :       304 elements
# Info    : 0.60 < quality < 0.70 :       178 elements
# Info    : 0.70 < quality < 0.80 :       196 elements
# Info    : 0.80 < quality < 0.90 :        62 elements
# Info    : 0.90 < quality < 1.00 :        22 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 2253.31) with worst = 0.0296484 / average = 0.70814:
# Info    : 0.00 < quality < 0.10 :         6 elements
# Info    : 0.10 < quality < 0.20 :        18 elements
# Info    : 0.20 < quality < 0.30 :        36 elements
# Info    : 0.30 < quality < 0.40 :        56 elements
# Info    : 0.40 < quality < 0.50 :        85 elements
# Info    : 0.50 < quality < 0.60 :       290 elements
# Info    : 0.60 < quality < 0.70 :       788 elements
# Info    : 0.70 < quality < 0.80 :      1002 elements
# Info    : 0.80 < quality < 0.90 :       420 elements
# Info    : 0.90 < quality < 1.00 :       255 elements
# Info    : 54 edge swaps, 2 node relocations (volume = 2253.31): worst = 0.17631 / average = 0.718799 (Wall 0.000617027s, CPU 0.00064s)
# Info    : 57 edge swaps, 2 node relocations (volume = 2253.31): worst = 0.301559 / average = 0.719391 (Wall 0.000767296s, CPU 0.000802s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        46 elements
# Info    : 0.40 < quality < 0.50 :        94 elements
# Info    : 0.50 < quality < 0.60 :       293 elements
# Info    : 0.60 < quality < 0.70 :       780 elements
# Info    : 0.70 < quality < 0.80 :      1013 elements
# Info    : 0.80 < quality < 0.90 :       423 elements
# Info    : 0.90 < quality < 1.00 :       255 elements
# Info    : Optimizing volume 4
# Info    : Optimization starts (volume = 364.8) with worst = 0.0883297 / average = 0.526201:
# Info    : 0.00 < quality < 0.10 :         6 elements
# Info    : 0.10 < quality < 0.20 :         7 elements
# Info    : 0.20 < quality < 0.30 :        13 elements
# Info    : 0.30 < quality < 0.40 :        60 elements
# Info    : 0.40 < quality < 0.50 :       974 elements
# Info    : 0.50 < quality < 0.60 :       302 elements
# Info    : 0.60 < quality < 0.70 :       182 elements
# Info    : 0.70 < quality < 0.80 :       196 elements
# Info    : 0.80 < quality < 0.90 :        60 elements
# Info    : 0.90 < quality < 1.00 :        22 elements
# Info    : 4 edge swaps, 8 node relocations (volume = 364.8): worst = 0.0883297 / average = 0.52717 (Wall 0.000277149s, CPU 0.000298s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         6 elements
# Info    : 0.10 < quality < 0.20 :         4 elements
# Info    : 0.20 < quality < 0.30 :        10 elements
# Info    : 0.30 < quality < 0.40 :        60 elements
# Info    : 0.40 < quality < 0.50 :       977 elements
# Info    : 0.50 < quality < 0.60 :       304 elements
# Info    : 0.60 < quality < 0.70 :       180 elements
# Info    : 0.70 < quality < 0.80 :       197 elements
# Info    : 0.80 < quality < 0.90 :        60 elements
# Info    : 0.90 < quality < 1.00 :        22 elements
# Info    : Optimizing volume 5
# Info    : Optimization starts (volume = 364.8) with worst = 0.000731071 / average = 0.528337:
# Info    : 0.00 < quality < 0.10 :         6 elements
# Info    : 0.10 < quality < 0.20 :         7 elements
# Info    : 0.20 < quality < 0.30 :         9 elements
# Info    : 0.30 < quality < 0.40 :        46 elements
# Info    : 0.40 < quality < 0.50 :       968 elements
# Info    : 0.50 < quality < 0.60 :       304 elements
# Info    : 0.60 < quality < 0.70 :       189 elements
# Info    : 0.70 < quality < 0.80 :       182 elements
# Info    : 0.80 < quality < 0.90 :        71 elements
# Info    : 0.90 < quality < 1.00 :        21 elements
# Info    : 6 edge swaps, 4 node relocations (volume = 364.8): worst = 0.000731071 / average = 0.529205 (Wall 0.000268489s, CPU 0.000289s)
# Info    : 0.00 < quality < 0.10 :         5 elements
# Info    : 0.10 < quality < 0.20 :         2 elements
# Info    : 0.20 < quality < 0.30 :         8 elements
# Info    : 0.30 < quality < 0.40 :        47 elements
# Info    : 0.40 < quality < 0.50 :       972 elements
# Info    : 0.50 < quality < 0.60 :       302 elements
# Info    : 0.60 < quality < 0.70 :       192 elements
# Info    : 0.70 < quality < 0.80 :       179 elements
# Info    : 0.80 < quality < 0.90 :        71 elements
# Info    : 0.90 < quality < 1.00 :        20 elements
# Info    : Done optimizing mesh (Wall 0.00754163s, CPU 0.008099s)
# Info    : 2342 nodes 15232 elements
# Info    : Meshing order 2 (curvilinear on)...
# Info    : [  0%] Meshing curve 13 order 2
# Info    : [ 10%] Meshing curve 14 order 2
# Info    : [ 10%] Meshing curve 15 order 2
# Info    : [ 10%] Meshing curve 16 order 2
# Info    : [ 10%] Meshing curve 17 order 2
# Info    : [ 10%] Meshing curve 18 order 2
# Info    : [ 10%] Meshing curve 19 order 2
# Info    : [ 10%] Meshing curve 20 order 2
# Info    : [ 20%] Meshing curve 21 order 2
# Info    : [ 20%] Meshing curve 22 order 2
# Info    : [ 20%] Meshing curve 23 order 2
# Info    : [ 20%] Meshing curve 24 order 2
# Info    : [ 20%] Meshing curve 25 order 2
# Info    : [ 20%] Meshing curve 26 order 2
# Info    : [ 20%] Meshing curve 27 order 2
# Info    : [ 30%] Meshing curve 28 order 2
# Info    : [ 30%] Meshing curve 29 order 2
# Info    : [ 30%] Meshing curve 30 order 2
# Info    : [ 30%] Meshing curve 31 order 2
# Info    : [ 30%] Meshing curve 32 order 2
# Info    : [ 30%] Meshing curve 33 order 2
# Info    : [ 30%] Meshing curve 34 order 2
# Info    : [ 30%] Meshing curve 35 order 2
# Info    : [ 40%] Meshing curve 36 order 2
# Info    : [ 40%] Meshing curve 37 order 2
# Info    : [ 40%] Meshing curve 38 order 2
# Info    : [ 40%] Meshing curve 39 order 2
# Info    : [ 40%] Meshing curve 40 order 2
# Info    : [ 40%] Meshing curve 41 order 2
# Info    : [ 40%] Meshing curve 42 order 2
# Info    : [ 50%] Meshing curve 43 order 2
# Info    : [ 50%] Meshing curve 44 order 2
# Info    : [ 50%] Meshing curve 45 order 2
# Info    : [ 50%] Meshing curve 46 order 2
# Info    : [ 50%] Meshing curve 47 order 2
# Info    : [ 50%] Meshing curve 48 order 2
# Info    : [ 50%] Meshing curve 49 order 2
# Info    : [ 50%] Meshing curve 50 order 2
# Info    : [ 60%] Meshing curve 51 order 2
# Info    : [ 60%] Meshing curve 52 order 2
# Info    : [ 60%] Meshing curve 53 order 2
# Info    : [ 60%] Meshing curve 54 order 2
# Info    : [ 60%] Meshing curve 55 order 2
# Info    : [ 60%] Meshing curve 56 order 2
# Info    : [ 60%] Meshing surface 7 order 2
# Info    : [ 70%] Meshing surface 8 order 2
# Info    : [ 70%] Meshing surface 9 order 2
# Info    : [ 70%] Meshing surface 10 order 2
# Info    : [ 70%] Meshing surface 11 order 2
# Info    : [ 70%] Meshing surface 12 order 2
# Info    : [ 70%] Meshing surface 13 order 2
# Info    : [ 70%] Meshing surface 14 order 2
# Info    : [ 70%] Meshing surface 15 order 2
# Info    : [ 80%] Meshing surface 16 order 2
# Info    : [ 80%] Meshing surface 17 order 2
# Info    : [ 80%] Meshing surface 18 order 2
# Info    : [ 80%] Meshing surface 19 order 2
# Info    : [ 80%] Meshing surface 20 order 2
# Info    : [ 80%] Meshing surface 21 order 2
# Info    : [ 80%] Meshing surface 22 order 2
# Info    : [ 90%] Meshing surface 23 order 2
# Info    : [ 90%] Meshing surface 24 order 2
# Info    : [ 90%] Meshing surface 25 order 2
# Info    : [ 90%] Meshing surface 26 order 2
# Info    : [ 90%] Meshing surface 27 order 2
# Info    : [ 90%] Meshing surface 28 order 2
# Info    : [ 90%] Meshing surface 29 order 2
# Info    : [ 90%] Meshing surface 30 order 2
# Info    : [100%] Meshing surface 31 order 2
# Info    : [100%] Meshing surface 32 order 2
# Info    : [100%] Meshing volume 1 order 2
# Info    : [100%] Meshing volume 2 order 2
# Info    : [100%] Meshing volume 3 order 2
# Info    : [100%] Meshing volume 4 order 2
# Info    : [100%] Meshing volume 5 order 2
# Info    : Surface mesh: worst distortion = 1 (0 elements in ]0, 0.2]); worst gamma = 0.352274
# Info    : Volume mesh: worst distortion = 1 (0 elements in ]0, 0.2])
# Info    : Done meshing order 2 (Wall 0.0303243s, CPU 0.031193s)
# Info    : Writing 'output/TFP1/geo/composite_layers.inp'...
# Info    : Done writing 'output/TFP1/geo/composite_layers.inp'
# Warning : 1 ill-shaped tets are still in the mesh
# Warning : ------------------------------
# Warning : Mesh generation error summary
# Warning :     1 warning
# Warning :     0 errors
# Warning : Check the full log for details
# Warning : ------------------------------
# Running Calculix at:  output/TFP1/sim
# Output file:  /home/djoroya/projects/CITISENS/CITISENS_Composite/scripts/T02_Modelo_MultiCapa/T02_NumericalModel/output/TFP1/sim/out.txt
# Command:
#  wine /home/djoroya/projects/CITISENS/CITISENS_Composite/src/djccx/bin/ccx_dynamic.exe main > out.txt
# Error reading cvf file
#
# pid:  1401123
#
# Calculix finished
#
# ['Y', 'Y', 'nucleo', 'Y', 'Y']
# Time Step:
# Time Step:
# Time Step:
# Running Calculix at:  output/TFP1/tensile
# Output file:  /home/djoroya/projects/CITISENS/CITISENS_Composite/scripts/T02_Modelo_MultiCapa/T02_NumericalModel/output/TFP1/tensile/out.txt
# Command:
#  wine /home/djoroya/projects/CITISENS/CITISENS_Composite/src/djccx/bin/ccx_dynamic.exe main > out.txt
# Error reading cvf file
#
# pid:  1401345
#
# Calculix finished
#
# ['Y', 'Y', 'nucleo', 'Y', 'Y']
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 13 (Line)
# Info    : [ 10%] Meshing curve 14 (Line)
# Info    : [ 10%] Meshing curve 15 (Line)
# Info    : [ 10%] Meshing curve 16 (Line)
# Info    : [ 10%] Meshing curve 17 (Line)
# Info    : [ 20%] Meshing curve 18 (Line)
# Info    : [ 20%] Meshing curve 19 (Line)
# Info    : [ 20%] Meshing curve 20 (Line)
# Info    : [ 20%] Meshing curve 21 (Line)
# Info    : [ 30%] Meshing curve 22 (Line)
# Info    : [ 30%] Meshing curve 23 (Line)
# Info    : [ 30%] Meshing curve 24 (Line)
# Info    : [ 30%] Meshing curve 25 (Line)
# Info    : [ 30%] Meshing curve 26 (Line)
# Info    : [ 40%] Meshing curve 27 (Line)
# Info    : [ 40%] Meshing curve 28 (Line)
# Info    : [ 40%] Meshing curve 29 (Line)
# Info    : [ 40%] Meshing curve 30 (Line)
# Info    : [ 50%] Meshing curve 31 (Line)
# Info    : [ 50%] Meshing curve 32 (Line)
# Info    : [ 50%] Meshing curve 33 (Line)
# Info    : [ 50%] Meshing curve 34 (Line)
# Info    : [ 60%] Meshing curve 35 (Line)
# Info    : [ 60%] Meshing curve 36 (Line)
# Info    : [ 60%] Meshing curve 37 (Line)
# Info    : [ 60%] Meshing curve 38 (Line)
# Info    : [ 60%] Meshing curve 39 (Line)
# Info    : [ 70%] Meshing curve 40 (Line)
# Info    : [ 70%] Meshing curve 41 (Line)
# Info    : [ 70%] Meshing curve 42 (Line)
# Info    : [ 70%] Meshing curve 43 (Line)
# Info    : [ 80%] Meshing curve 44 (Line)
# Info    : [ 80%] Meshing curve 45 (Line)
# Info    : [ 80%] Meshing curve 46 (Line)
# Info    : [ 80%] Meshing curve 47 (Line)
# Info    : [ 80%] Meshing curve 48 (Line)
# Info    : [ 90%] Meshing curve 49 (Line)
# Info    : [ 90%] Meshing curve 50 (Line)
# Info    : [ 90%] Meshing curve 51 (Line)
# Info    : [ 90%] Meshing curve 52 (Line)
# Info    : [100%] Meshing curve 53 (Line)
# Info    : [100%] Meshing curve 54 (Line)
# Info    : [100%] Meshing curve 55 (Line)
# Info    : [100%] Meshing curve 56 (Line)
# Info    : Done meshing 1D (Wall 0.0157796s, CPU 0.01627s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 7 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 8 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 9 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 10 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 13 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 14 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 15 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 16 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 17 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 18 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 19 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 20 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 21 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 22 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 23 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 24 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 25 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 26 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 27 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 28 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 29 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 30 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 31 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 32 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0373828s, CPU 0.037454s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 5 volumes with 1 connected component
# Info    : Tetrahedrizing 2218 nodes...
# Info    : Done tetrahedrizing 2226 nodes (Wall 0.0205492s, CPU 0.020467s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 32 Steiner points
# Info    : Done reconstructing mesh (Wall 0.0675167s, CPU 0.06748s)
# Info    : Found volume 3
# Info    : Found volume 4
# Info    : Found volume 2
# Info    : Found volume 1
# Info    : Found volume 5
# Info    : It. 0 - 0 nodes created - worst tet radius 5.15603 (nodes removed 0 0)
# Info    : 3D refinement terminated (2374 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 55 nodes could not be inserted
# Info    :  - 10475 tetrahedra created in 0.00519959 sec. (2014581 tets/s)
# Info    : 46 node relocations
# Info    : Done meshing 3D (Wall 0.115213s, CPU 0.115648s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 364.325) with worst = 0.00131693 / average = 0.523149:
# Info    : 0.00 < quality < 0.10 :        22 elements
# Info    : 0.10 < quality < 0.20 :        12 elements
# Info    : 0.20 < quality < 0.30 :        10 elements
# Info    : 0.30 < quality < 0.40 :        90 elements
# Info    : 0.40 < quality < 0.50 :       954 elements
# Info    : 0.50 < quality < 0.60 :       307 elements
# Info    : 0.60 < quality < 0.70 :       196 elements
# Info    : 0.70 < quality < 0.80 :       190 elements
# Info    : 0.80 < quality < 0.90 :        72 elements
# Info    : 0.90 < quality < 1.00 :        24 elements
# Info    : 23 edge swaps, 8 node relocations (volume = 364.325): worst = 0.00131693 / average = 0.528016 (Wall 0.000424338s, CPU 0.000458s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         8 elements
# Info    : 0.10 < quality < 0.20 :         7 elements
# Info    : 0.20 < quality < 0.30 :         8 elements
# Info    : 0.30 < quality < 0.40 :        88 elements
# Info    : 0.40 < quality < 0.50 :       963 elements
# Info    : 0.50 < quality < 0.60 :       303 elements
# Info    : 0.60 < quality < 0.70 :       198 elements
# Info    : 0.70 < quality < 0.80 :       187 elements
# Info    : 0.80 < quality < 0.90 :        72 elements
# Info    : 0.90 < quality < 1.00 :        24 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 364.325) with worst = 0.0820391 / average = 0.526206:
# Info    : 0.00 < quality < 0.10 :         7 elements
# Info    : 0.10 < quality < 0.20 :        16 elements
# Info    : 0.20 < quality < 0.30 :        13 elements
# Info    : 0.30 < quality < 0.40 :        84 elements
# Info    : 0.40 < quality < 0.50 :       953 elements
# Info    : 0.50 < quality < 0.60 :       311 elements
# Info    : 0.60 < quality < 0.70 :       198 elements
# Info    : 0.70 < quality < 0.80 :       195 elements
# Info    : 0.80 < quality < 0.90 :        71 elements
# Info    : 0.90 < quality < 1.00 :        22 elements
# Info    : 7 edge swaps, 5 node relocations (volume = 364.325): worst = 0.0820391 / average = 0.526835 (Wall 0.000337209s, CPU 0.000325s)
# Info    : 10 edge swaps, 6 node relocations (volume = 364.325): worst = 0.0820391 / average = 0.527052 (Wall 0.000584617s, CPU 0.000606s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         6 elements
# Info    : 0.10 < quality < 0.20 :        14 elements
# Info    : 0.20 < quality < 0.30 :         9 elements
# Info    : 0.30 < quality < 0.40 :        84 elements
# Info    : 0.40 < quality < 0.50 :       951 elements
# Info    : 0.50 < quality < 0.60 :       313 elements
# Info    : 0.60 < quality < 0.70 :       198 elements
# Info    : 0.70 < quality < 0.80 :       194 elements
# Info    : 0.80 < quality < 0.90 :        71 elements
# Info    : 0.90 < quality < 1.00 :        22 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 2250.38) with worst = 0.0384677 / average = 0.711771:
# Info    : 0.00 < quality < 0.10 :         9 elements
# Info    : 0.10 < quality < 0.20 :        16 elements
# Info    : 0.20 < quality < 0.30 :        32 elements
# Info    : 0.30 < quality < 0.40 :        42 elements
# Info    : 0.40 < quality < 0.50 :        90 elements
# Info    : 0.50 < quality < 0.60 :       271 elements
# Info    : 0.60 < quality < 0.70 :       813 elements
# Info    : 0.70 < quality < 0.80 :      1016 elements
# Info    : 0.80 < quality < 0.90 :       459 elements
# Info    : 0.90 < quality < 1.00 :       264 elements
# Info    : 53 edge swaps, 1 node relocations (volume = 2250.38): worst = 0.255724 / average = 0.720917 (Wall 0.000640777s, CPU 0.000686s)
# Info    : 55 edge swaps, 1 node relocations (volume = 2250.38): worst = 0.303222 / average = 0.721117 (Wall 0.000804656s, CPU 0.000884s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        43 elements
# Info    : 0.40 < quality < 0.50 :       102 elements
# Info    : 0.50 < quality < 0.60 :       265 elements
# Info    : 0.60 < quality < 0.70 :       813 elements
# Info    : 0.70 < quality < 0.80 :      1022 elements
# Info    : 0.80 < quality < 0.90 :       461 elements
# Info    : 0.90 < quality < 1.00 :       262 elements
# Info    : Optimizing volume 4
# Info    : Optimization starts (volume = 364.325) with worst = 0.0820391 / average = 0.531644:
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :         7 elements
# Info    : 0.20 < quality < 0.30 :        10 elements
# Info    : 0.30 < quality < 0.40 :        63 elements
# Info    : 0.40 < quality < 0.50 :       968 elements
# Info    : 0.50 < quality < 0.60 :       300 elements
# Info    : 0.60 < quality < 0.70 :       198 elements
# Info    : 0.70 < quality < 0.80 :       198 elements
# Info    : 0.80 < quality < 0.90 :        70 elements
# Info    : 0.90 < quality < 1.00 :        24 elements
# Info    : 7 edge swaps, 3 node relocations (volume = 364.325): worst = 0.0820391 / average = 0.532981 (Wall 0.000252039s, CPU 0.000294s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         2 elements
# Info    : 0.10 < quality < 0.20 :         2 elements
# Info    : 0.20 < quality < 0.30 :         8 elements
# Info    : 0.30 < quality < 0.40 :        64 elements
# Info    : 0.40 < quality < 0.50 :       975 elements
# Info    : 0.50 < quality < 0.60 :       298 elements
# Info    : 0.60 < quality < 0.70 :       200 elements
# Info    : 0.70 < quality < 0.80 :       195 elements
# Info    : 0.80 < quality < 0.90 :        70 elements
# Info    : 0.90 < quality < 1.00 :        24 elements
# Info    : Optimizing volume 5
# Info    : Optimization starts (volume = 364.325) with worst = 0.00587602 / average = 0.524247:
# Info    : 0.00 < quality < 0.10 :        15 elements
# Info    : 0.10 < quality < 0.20 :        15 elements
# Info    : 0.20 < quality < 0.30 :        13 elements
# Info    : 0.30 < quality < 0.40 :        75 elements
# Info    : 0.40 < quality < 0.50 :       968 elements
# Info    : 0.50 < quality < 0.60 :       311 elements
# Info    : 0.60 < quality < 0.70 :       188 elements
# Info    : 0.70 < quality < 0.80 :       195 elements
# Info    : 0.80 < quality < 0.90 :        73 elements
# Info    : 0.90 < quality < 1.00 :        22 elements
# Info    : 21 edge swaps, 10 node relocations (volume = 364.325): worst = 0.0989326 / average = 0.528718 (Wall 0.000376288s, CPU 0.000413s)
# Info    : 22 edge swaps, 12 node relocations (volume = 364.325): worst = 0.0989326 / average = 0.52871 (Wall 0.000571177s, CPU 0.000624s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :        11 elements
# Info    : 0.20 < quality < 0.30 :        11 elements
# Info    : 0.30 < quality < 0.40 :        74 elements
# Info    : 0.40 < quality < 0.50 :       970 elements
# Info    : 0.50 < quality < 0.60 :       312 elements
# Info    : 0.60 < quality < 0.70 :       188 elements
# Info    : 0.70 < quality < 0.80 :       194 elements
# Info    : 0.80 < quality < 0.90 :        73 elements
# Info    : 0.90 < quality < 1.00 :        22 elements
# Info    : Done optimizing mesh (Wall 0.00811804s, CPU 0.008753s)
# Info    : 2374 nodes 15469 elements
# Info    : Meshing order 2 (curvilinear on)...
# Info    : [  0%] Meshing curve 13 order 2
# Info    : [ 10%] Meshing curve 14 order 2
# Info    : [ 10%] Meshing curve 15 order 2
# Info    : [ 10%] Meshing curve 16 order 2
# Info    : [ 10%] Meshing curve 17 order 2
# Info    : [ 10%] Meshing curve 18 order 2
# Info    : [ 10%] Meshing curve 19 order 2
# Info    : [ 10%] Meshing curve 20 order 2
# Info    : [ 20%] Meshing curve 21 order 2
# Info    : [ 20%] Meshing curve 22 order 2
# Info    : [ 20%] Meshing curve 23 order 2
# Info    : [ 20%] Meshing curve 24 order 2
# Info    : [ 20%] Meshing curve 25 order 2
# Info    : [ 20%] Meshing curve 26 order 2
# Info    : [ 20%] Meshing curve 27 order 2
# Info    : [ 30%] Meshing curve 28 order 2
# Info    : [ 30%] Meshing curve 29 order 2
# Info    : [ 30%] Meshing curve 30 order 2
# Info    : [ 30%] Meshing curve 31 order 2
# Info    : [ 30%] Meshing curve 32 order 2
# Info    : [ 30%] Meshing curve 33 order 2
# Info    : [ 30%] Meshing curve 34 order 2
# Info    : [ 30%] Meshing curve 35 order 2
# Info    : [ 40%] Meshing curve 36 order 2
# Info    : [ 40%] Meshing curve 37 order 2
# Info    : [ 40%] Meshing curve 38 order 2
# Info    : [ 40%] Meshing curve 39 order 2
# Info    : [ 40%] Meshing curve 40 order 2
# Info    : [ 40%] Meshing curve 41 order 2
# Info    : [ 40%] Meshing curve 42 order 2
# Info    : [ 50%] Meshing curve 43 order 2
# Info    : [ 50%] Meshing curve 44 order 2
# Info    : [ 50%] Meshing curve 45 order 2
# Info    : [ 50%] Meshing curve 46 order 2
# Info    : [ 50%] Meshing curve 47 order 2
# Info    : [ 50%] Meshing curve 48 order 2
# Info    : [ 50%] Meshing curve 49 order 2
# Info    : [ 50%] Meshing curve 50 order 2
# Info    : [ 60%] Meshing curve 51 order 2
# Info    : [ 60%] Meshing curve 52 order 2
# Info    : [ 60%] Meshing curve 53 order 2
# Info    : [ 60%] Meshing curve 54 order 2
# Info    : [ 60%] Meshing curve 55 order 2
# Info    : [ 60%] Meshing curve 56 order 2
# Info    : [ 60%] Meshing surface 7 order 2
# Info    : [ 70%] Meshing surface 8 order 2
# Info    : [ 70%] Meshing surface 9 order 2
# Info    : [ 70%] Meshing surface 10 order 2
# Info    : [ 70%] Meshing surface 11 order 2
# Info    : [ 70%] Meshing surface 12 order 2
# Info    : [ 70%] Meshing surface 13 order 2
# Info    : [ 70%] Meshing surface 14 order 2
# Info    : [ 70%] Meshing surface 15 order 2
# Info    : [ 80%] Meshing surface 16 order 2
# Info    : [ 80%] Meshing surface 17 order 2
# Info    : [ 80%] Meshing surface 18 order 2
# Info    : [ 80%] Meshing surface 19 order 2
# Info    : [ 80%] Meshing surface 20 order 2
# Info    : [ 80%] Meshing surface 21 order 2
# Info    : [ 80%] Meshing surface 22 order 2
# Info    : [ 90%] Meshing surface 23 order 2
# Info    : [ 90%] Meshing surface 24 order 2
# Info    : [ 90%] Meshing surface 25 order 2
# Info    : [ 90%] Meshing surface 26 order 2
# Info    : [ 90%] Meshing surface 27 order 2
# Info    : [ 90%] Meshing surface 28 order 2
# Info    : [ 90%] Meshing surface 29 order 2
# Info    : [ 90%] Meshing surface 30 order 2
# Info    : [100%] Meshing surface 31 order 2
# Info    : [100%] Meshing surface 32 order 2
# Info    : [100%] Meshing volume 1 order 2
# Info    : [100%] Meshing volume 2 order 2
# Info    : [100%] Meshing volume 3 order 2
# Info    : [100%] Meshing volume 4 order 2
# Info    : [100%] Meshing volume 5 order 2
# Info    : Surface mesh: worst distortion = 1 (0 elements in ]0, 0.2]); worst gamma = 0.35245
# Info    : Volume mesh: worst distortion = 1 (0 elements in ]0, 0.2])
# Info    : Done meshing order 2 (Wall 0.0313683s, CPU 0.032138s)
# Info    : Writing 'output/TFP2/geo/composite_layers.inp'...
# Info    : Done writing 'output/TFP2/geo/composite_layers.inp'
# Running Calculix at:  output/TFP2/sim
# Output file:  /home/djoroya/projects/CITISENS/CITISENS_Composite/scripts/T02_Modelo_MultiCapa/T02_NumericalModel/output/TFP2/sim/out.txt
# Command:
#  wine /home/djoroya/projects/CITISENS/CITISENS_Composite/src/djccx/bin/ccx_dynamic.exe main > out.txt
# Error reading cvf file
#
# pid:  1401569
#
# Calculix finished
#
# ['X', 'Y', 'nucleo', 'Y', 'X']
# Time Step:
# Time Step:
# Time Step:
# Running Calculix at:  output/TFP2/tensile
# Output file:  /home/djoroya/projects/CITISENS/CITISENS_Composite/scripts/T02_Modelo_MultiCapa/T02_NumericalModel/output/TFP2/tensile/out.txt
# Command:
#  wine /home/djoroya/projects/CITISENS/CITISENS_Composite/src/djccx/bin/ccx_dynamic.exe main > out.txt
# Error reading cvf file
#
# pid:  1401791
#
# Calculix finished
#
# ['X', 'Y', 'nucleo', 'Y', 'X']
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 13 (Line)
# Info    : [ 10%] Meshing curve 14 (Line)
# Info    : [ 10%] Meshing curve 15 (Line)
# Info    : [ 10%] Meshing curve 16 (Line)
# Info    : [ 10%] Meshing curve 17 (Line)
# Info    : [ 20%] Meshing curve 18 (Line)
# Info    : [ 20%] Meshing curve 19 (Line)
# Info    : [ 20%] Meshing curve 20 (Line)
# Info    : [ 20%] Meshing curve 21 (Line)
# Info    : [ 30%] Meshing curve 22 (Line)
# Info    : [ 30%] Meshing curve 23 (Line)
# Info    : [ 30%] Meshing curve 24 (Line)
# Info    : [ 30%] Meshing curve 25 (Line)
# Info    : [ 30%] Meshing curve 26 (Line)
# Info    : [ 40%] Meshing curve 27 (Line)
# Info    : [ 40%] Meshing curve 28 (Line)
# Info    : [ 40%] Meshing curve 29 (Line)
# Info    : [ 40%] Meshing curve 30 (Line)
# Info    : [ 50%] Meshing curve 31 (Line)
# Info    : [ 50%] Meshing curve 32 (Line)
# Info    : [ 50%] Meshing curve 33 (Line)
# Info    : [ 50%] Meshing curve 34 (Line)
# Info    : [ 60%] Meshing curve 35 (Line)
# Info    : [ 60%] Meshing curve 36 (Line)
# Info    : [ 60%] Meshing curve 37 (Line)
# Info    : [ 60%] Meshing curve 38 (Line)
# Info    : [ 60%] Meshing curve 39 (Line)
# Info    : [ 70%] Meshing curve 40 (Line)
# Info    : [ 70%] Meshing curve 41 (Line)
# Info    : [ 70%] Meshing curve 42 (Line)
# Info    : [ 70%] Meshing curve 43 (Line)
# Info    : [ 80%] Meshing curve 44 (Line)
# Info    : [ 80%] Meshing curve 45 (Line)
# Info    : [ 80%] Meshing curve 46 (Line)
# Info    : [ 80%] Meshing curve 47 (Line)
# Info    : [ 80%] Meshing curve 48 (Line)
# Info    : [ 90%] Meshing curve 49 (Line)
# Info    : [ 90%] Meshing curve 50 (Line)
# Info    : [ 90%] Meshing curve 51 (Line)
# Info    : [ 90%] Meshing curve 52 (Line)
# Info    : [100%] Meshing curve 53 (Line)
# Info    : [100%] Meshing curve 54 (Line)
# Info    : [100%] Meshing curve 55 (Line)
# Info    : [100%] Meshing curve 56 (Line)
# Info    : Done meshing 1D (Wall 0.0158409s, CPU 0.016424s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 7 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 8 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 9 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 10 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 13 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 14 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 15 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 16 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 17 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 18 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 19 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 20 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 21 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 22 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 23 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 24 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 25 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 26 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 27 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 28 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 29 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 30 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 31 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 32 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0377923s, CPU 0.038141s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 5 volumes with 1 connected component
# Info    : Tetrahedrizing 2239 nodes...
# Info    : Done tetrahedrizing 2247 nodes (Wall 0.020707s, CPU 0.020721s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 26 Steiner points
# Info    : Done reconstructing mesh (Wall 0.0615969s, CPU 0.061598s)
# Info    : Found volume 3
# Info    : Found volume 4
# Info    : Found volume 1
# Info    : Found volume 5
# Info    : Found volume 2
# Info    : It. 0 - 0 nodes created - worst tet radius 4.39027 (nodes removed 0 0)
# Info    : 3D refinement terminated (2383 nodes total):
# Info    :  - 2 Delaunay cavities modified for star shapeness
# Info    :  - 53 nodes could not be inserted
# Info    :  - 10494 tetrahedra created in 0.00536128 sec. (1957367 tets/s)
# Info    : 36 node relocations
# Info    : Done meshing 3D (Wall 0.109852s, CPU 0.110163s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 361.95) with worst = 0.000137688 / average = 0.529762:
# Info    : 0.00 < quality < 0.10 :        13 elements
# Info    : 0.10 < quality < 0.20 :         5 elements
# Info    : 0.20 < quality < 0.30 :        11 elements
# Info    : 0.30 < quality < 0.40 :        70 elements
# Info    : 0.40 < quality < 0.50 :       953 elements
# Info    : 0.50 < quality < 0.60 :       313 elements
# Info    : 0.60 < quality < 0.70 :       190 elements
# Info    : 0.70 < quality < 0.80 :       216 elements
# Info    : 0.80 < quality < 0.90 :        60 elements
# Info    : 0.90 < quality < 1.00 :        24 elements
# Info    : 13 edge swaps, 4 node relocations (volume = 361.95): worst = 0.000141037 / average = 0.532897 (Wall 0.000327158s, CPU 0.000926s)
# Info    : 14 edge swaps, 6 node relocations (volume = 361.95): worst = 0.000784289 / average = 0.533186 (Wall 0.000482177s, CPU 0.001115s)
# Info    : 0.00 < quality < 0.10 :         5 elements
# Info    : 0.10 < quality < 0.20 :         4 elements
# Info    : 0.20 < quality < 0.30 :         6 elements
# Info    : 0.30 < quality < 0.40 :        68 elements
# Info    : 0.40 < quality < 0.50 :       953 elements
# Info    : 0.50 < quality < 0.60 :       314 elements
# Info    : 0.60 < quality < 0.70 :       194 elements
# Info    : 0.70 < quality < 0.80 :       214 elements
# Info    : 0.80 < quality < 0.90 :        60 elements
# Info    : 0.90 < quality < 1.00 :        24 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 361.95) with worst = 0.103558 / average = 0.528434:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        18 elements
# Info    : 0.20 < quality < 0.30 :        13 elements
# Info    : 0.30 < quality < 0.40 :        87 elements
# Info    : 0.40 < quality < 0.50 :       948 elements
# Info    : 0.50 < quality < 0.60 :       308 elements
# Info    : 0.60 < quality < 0.70 :       200 elements
# Info    : 0.70 < quality < 0.80 :       207 elements
# Info    : 0.80 < quality < 0.90 :        67 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : 5 edge swaps, 12 node relocations (volume = 361.95): worst = 0.108634 / average = 0.529657 (Wall 0.000303419s, CPU 0.000331s)
# Info    : 6 edge swaps, 18 node relocations (volume = 361.95): worst = 0.108634 / average = 0.529656 (Wall 0.000508238s, CPU 0.000548s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        14 elements
# Info    : 0.20 < quality < 0.30 :         9 elements
# Info    : 0.30 < quality < 0.40 :        87 elements
# Info    : 0.40 < quality < 0.50 :       948 elements
# Info    : 0.50 < quality < 0.60 :       306 elements
# Info    : 0.60 < quality < 0.70 :       200 elements
# Info    : 0.70 < quality < 0.80 :       208 elements
# Info    : 0.80 < quality < 0.90 :        67 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 2235.71) with worst = 0.0137336 / average = 0.701546:
# Info    : 0.00 < quality < 0.10 :         8 elements
# Info    : 0.10 < quality < 0.20 :        27 elements
# Info    : 0.20 < quality < 0.30 :        37 elements
# Info    : 0.30 < quality < 0.40 :        65 elements
# Info    : 0.40 < quality < 0.50 :       113 elements
# Info    : 0.50 < quality < 0.60 :       286 elements
# Info    : 0.60 < quality < 0.70 :       810 elements
# Info    : 0.70 < quality < 0.80 :      1035 elements
# Info    : 0.80 < quality < 0.90 :       441 elements
# Info    : 0.90 < quality < 1.00 :       238 elements
# Info    : 68 edge swaps, 4 node relocations (volume = 2235.71): worst = 0.270608 / average = 0.712389 (Wall 0.000793015s, CPU 0.000827s)
# Info    : 69 edge swaps, 5 node relocations (volume = 2235.71): worst = 0.270821 / average = 0.712397 (Wall 0.000949475s, CPU 0.001015s)
# Info    : 70 edge swaps, 5 node relocations (volume = 2235.71): worst = 0.301665 / average = 0.712603 (Wall 0.00110298s, CPU 0.001188s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        67 elements
# Info    : 0.40 < quality < 0.50 :       124 elements
# Info    : 0.50 < quality < 0.60 :       290 elements
# Info    : 0.60 < quality < 0.70 :       799 elements
# Info    : 0.70 < quality < 0.80 :      1048 elements
# Info    : 0.80 < quality < 0.90 :       442 elements
# Info    : 0.90 < quality < 1.00 :       238 elements
# Info    : Optimizing volume 4
# Info    : Optimization starts (volume = 361.95) with worst = 0.072062 / average = 0.529207:
# Info    : 0.00 < quality < 0.10 :         2 elements
# Info    : 0.10 < quality < 0.20 :        16 elements
# Info    : 0.20 < quality < 0.30 :        10 elements
# Info    : 0.30 < quality < 0.40 :        80 elements
# Info    : 0.40 < quality < 0.50 :       952 elements
# Info    : 0.50 < quality < 0.60 :       315 elements
# Info    : 0.60 < quality < 0.70 :       192 elements
# Info    : 0.70 < quality < 0.80 :       210 elements
# Info    : 0.80 < quality < 0.90 :        66 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : 4 edge swaps, 6 node relocations (volume = 361.95): worst = 0.072062 / average = 0.530142 (Wall 0.000300108s, CPU 0.00032s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         2 elements
# Info    : 0.10 < quality < 0.20 :        13 elements
# Info    : 0.20 < quality < 0.30 :         8 elements
# Info    : 0.30 < quality < 0.40 :        81 elements
# Info    : 0.40 < quality < 0.50 :       953 elements
# Info    : 0.50 < quality < 0.60 :       312 elements
# Info    : 0.60 < quality < 0.70 :       194 elements
# Info    : 0.70 < quality < 0.80 :       210 elements
# Info    : 0.80 < quality < 0.90 :        66 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : Optimizing volume 5
# Info    : Optimization starts (volume = 361.95) with worst = 0.000784289 / average = 0.528784:
# Info    : 0.00 < quality < 0.10 :        11 elements
# Info    : 0.10 < quality < 0.20 :         6 elements
# Info    : 0.20 < quality < 0.30 :         4 elements
# Info    : 0.30 < quality < 0.40 :        67 elements
# Info    : 0.40 < quality < 0.50 :       966 elements
# Info    : 0.50 < quality < 0.60 :       315 elements
# Info    : 0.60 < quality < 0.70 :       205 elements
# Info    : 0.70 < quality < 0.80 :       200 elements
# Info    : 0.80 < quality < 0.90 :        55 elements
# Info    : 0.90 < quality < 1.00 :        21 elements
# Info    : 15 edge swaps, 2 node relocations (volume = 361.95): worst = 0.000784289 / average = 0.532373 (Wall 0.000271959s, CPU 0s)
# Info    : 16 edge swaps, 4 node relocations (volume = 361.95): worst = 0.000784289 / average = 0.532653 (Wall 0.000384738s, CPU 0s)
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :         2 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        67 elements
# Info    : 0.40 < quality < 0.50 :       966 elements
# Info    : 0.50 < quality < 0.60 :       314 elements
# Info    : 0.60 < quality < 0.70 :       204 elements
# Info    : 0.70 < quality < 0.80 :       202 elements
# Info    : 0.80 < quality < 0.90 :        55 elements
# Info    : 0.90 < quality < 1.00 :        21 elements
# Info    : Done optimizing mesh (Wall 0.00827462s, CPU 0.00888s)
# Info    : 2383 nodes 15529 elements
# Info    : Meshing order 2 (curvilinear on)...
# Info    : [  0%] Meshing curve 13 order 2
# Info    : [ 10%] Meshing curve 14 order 2
# Info    : [ 10%] Meshing curve 15 order 2
# Info    : [ 10%] Meshing curve 16 order 2
# Info    : [ 10%] Meshing curve 17 order 2
# Info    : [ 10%] Meshing curve 18 order 2
# Info    : [ 10%] Meshing curve 19 order 2
# Info    : [ 10%] Meshing curve 20 order 2
# Info    : [ 20%] Meshing curve 21 order 2
# Info    : [ 20%] Meshing curve 22 order 2
# Info    : [ 20%] Meshing curve 23 order 2
# Info    : [ 20%] Meshing curve 24 order 2
# Info    : [ 20%] Meshing curve 25 order 2
# Info    : [ 20%] Meshing curve 26 order 2
# Info    : [ 20%] Meshing curve 27 order 2
# Info    : [ 30%] Meshing curve 28 order 2
# Info    : [ 30%] Meshing curve 29 order 2
# Info    : [ 30%] Meshing curve 30 order 2
# Info    : [ 30%] Meshing curve 31 order 2
# Info    : [ 30%] Meshing curve 32 order 2
# Info    : [ 30%] Meshing curve 33 order 2
# Info    : [ 30%] Meshing curve 34 order 2
# Info    : [ 30%] Meshing curve 35 order 2
# Info    : [ 40%] Meshing curve 36 order 2
# Info    : [ 40%] Meshing curve 37 order 2
# Info    : [ 40%] Meshing curve 38 order 2
# Info    : [ 40%] Meshing curve 39 order 2
# Info    : [ 40%] Meshing curve 40 order 2
# Info    : [ 40%] Meshing curve 41 order 2
# Info    : [ 40%] Meshing curve 42 order 2
# Info    : [ 50%] Meshing curve 43 order 2
# Info    : [ 50%] Meshing curve 44 order 2
# Info    : [ 50%] Meshing curve 45 order 2
# Info    : [ 50%] Meshing curve 46 order 2
# Info    : [ 50%] Meshing curve 47 order 2
# Info    : [ 50%] Meshing curve 48 order 2
# Info    : [ 50%] Meshing curve 49 order 2
# Info    : [ 50%] Meshing curve 50 order 2
# Info    : [ 60%] Meshing curve 51 order 2
# Info    : [ 60%] Meshing curve 52 order 2
# Info    : [ 60%] Meshing curve 53 order 2
# Info    : [ 60%] Meshing curve 54 order 2
# Info    : [ 60%] Meshing curve 55 order 2
# Info    : [ 60%] Meshing curve 56 order 2
# Info    : [ 60%] Meshing surface 7 order 2
# Info    : [ 70%] Meshing surface 8 order 2
# Info    : [ 70%] Meshing surface 9 order 2
# Info    : [ 70%] Meshing surface 10 order 2
# Info    : [ 70%] Meshing surface 11 order 2
# Info    : [ 70%] Meshing surface 12 order 2
# Info    : [ 70%] Meshing surface 13 order 2
# Info    : [ 70%] Meshing surface 14 order 2
# Info    : [ 70%] Meshing surface 15 order 2
# Info    : [ 80%] Meshing surface 16 order 2
# Info    : [ 80%] Meshing surface 17 order 2
# Info    : [ 80%] Meshing surface 18 order 2
# Info    : [ 80%] Meshing surface 19 order 2
# Info    : [ 80%] Meshing surface 20 order 2
# Info    : [ 80%] Meshing surface 21 order 2
# Info    : [ 80%] Meshing surface 22 order 2
# Info    : [ 90%] Meshing surface 23 order 2
# Info    : [ 90%] Meshing surface 24 order 2
# Info    : [ 90%] Meshing surface 25 order 2
# Info    : [ 90%] Meshing surface 26 order 2
# Info    : [ 90%] Meshing surface 27 order 2
# Info    : [ 90%] Meshing surface 28 order 2
# Info    : [ 90%] Meshing surface 29 order 2
# Info    : [ 90%] Meshing surface 30 order 2
# Info    : [100%] Meshing surface 31 order 2
# Info    : [100%] Meshing surface 32 order 2
# Info    : [100%] Meshing volume 1 order 2
# ...
# Info    : Found volume 3
# Info    : It. 0 - 0 nodes created - worst tet radius 4.81409 (nodes removed 0 0)
# Info    : 3D refinement terminated (3109 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 68 nodes could not be inserted
# Info    :  - 14332 tetrahedra created in 0.00607696 sec. (2358416 tets/s)
# Info    : 57 node relocations
# Info    : Done meshing 3D (Wall 0.154823s, CPU 0.155672s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 356.725) with worst = 0.00155834 / average = 0.531513:
# Info    : 0.00 < quality < 0.10 :        19 elements
# Info    : 0.10 < quality < 0.20 :         9 elements
# Info    : 0.20 < quality < 0.30 :        13 elements
# Info    : 0.30 < quality < 0.40 :        48 elements
# Info    : 0.40 < quality < 0.50 :       979 elements
# Info    : 0.50 < quality < 0.60 :       282 elements
# Info    : 0.60 < quality < 0.70 :       215 elements
# Info    : 0.70 < quality < 0.80 :       237 elements
# Info    : 0.80 < quality < 0.90 :        58 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : 17 edge swaps, 7 node relocations (volume = 356.725): worst = 0.00155834 / average = 0.535688 (Wall 0.000401718s, CPU 0.000435s)
# Info    : 18 edge swaps, 10 node relocations (volume = 356.725): worst = 0.00155834 / average = 0.535951 (Wall 0.000622937s, CPU 0.000689s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         6 elements
# Info    : 0.10 < quality < 0.20 :         7 elements
# Info    : 0.20 < quality < 0.30 :        10 elements
# Info    : 0.30 < quality < 0.40 :        48 elements
# Info    : 0.40 < quality < 0.50 :       980 elements
# Info    : 0.50 < quality < 0.60 :       279 elements
# Info    : 0.60 < quality < 0.70 :       217 elements
# Info    : 0.70 < quality < 0.80 :       238 elements
# Info    : 0.80 < quality < 0.90 :        58 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 356.725) with worst = 0.079987 / average = 0.534738:
# Info    : 0.00 < quality < 0.10 :         6 elements
# Info    : 0.10 < quality < 0.20 :         6 elements
# Info    : 0.20 < quality < 0.30 :        11 elements
# Info    : 0.30 < quality < 0.40 :        46 elements
# Info    : 0.40 < quality < 0.50 :       993 elements
# Info    : 0.50 < quality < 0.60 :       280 elements
# Info    : 0.60 < quality < 0.70 :       216 elements
# Info    : 0.70 < quality < 0.80 :       234 elements
# Info    : 0.80 < quality < 0.90 :        57 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : 5 edge swaps, 7 node relocations (volume = 356.725): worst = 0.079987 / average = 0.535692 (Wall 0.000265638s, CPU 0.000299s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         6 elements
# Info    : 0.10 < quality < 0.20 :         4 elements
# Info    : 0.20 < quality < 0.30 :         8 elements
# Info    : 0.30 < quality < 0.40 :        46 elements
# Info    : 0.40 < quality < 0.50 :       994 elements
# Info    : 0.50 < quality < 0.60 :       277 elements
# Info    : 0.60 < quality < 0.70 :       218 elements
# Info    : 0.70 < quality < 0.80 :       235 elements
# Info    : 0.80 < quality < 0.90 :        57 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 356.725) with worst = 0.10237 / average = 0.534125:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        10 elements
# Info    : 0.20 < quality < 0.30 :        13 elements
# Info    : 0.30 < quality < 0.40 :        60 elements
# Info    : 0.40 < quality < 0.50 :       989 elements
# Info    : 0.50 < quality < 0.60 :       272 elements
# Info    : 0.60 < quality < 0.70 :       219 elements
# Info    : 0.70 < quality < 0.80 :       238 elements
# Info    : 0.80 < quality < 0.90 :        53 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : 7 edge swaps, 3 node relocations (volume = 356.725): worst = 0.10237 / average = 0.534723 (Wall 0.000288999s, CPU 0.000319s)
# Info    : 8 edge swaps, 5 node relocations (volume = 356.725): worst = 0.10237 / average = 0.534723 (Wall 0.000465788s, CPU 0.00053s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         8 elements
# Info    : 0.20 < quality < 0.30 :         8 elements
# Info    : 0.30 < quality < 0.40 :        63 elements
# Info    : 0.40 < quality < 0.50 :       987 elements
# Info    : 0.50 < quality < 0.60 :       270 elements
# Info    : 0.60 < quality < 0.70 :       223 elements
# Info    : 0.70 < quality < 0.80 :       236 elements
# Info    : 0.80 < quality < 0.90 :        52 elements
# Info    : 0.90 < quality < 1.00 :        20 elements
# Info    : Optimizing volume 4
# Info    : Optimization starts (volume = 2203.43) with worst = 0.0155005 / average = 0.71089:
# Info    : 0.00 < quality < 0.10 :         9 elements
# Info    : 0.10 < quality < 0.20 :        19 elements
# Info    : 0.20 < quality < 0.30 :        35 elements
# Info    : 0.30 < quality < 0.40 :        47 elements
# Info    : 0.40 < quality < 0.50 :        80 elements
# Info    : 0.50 < quality < 0.60 :       281 elements
# Info    : 0.60 < quality < 0.70 :       805 elements
# Info    : 0.70 < quality < 0.80 :      1078 elements
# Info    : 0.80 < quality < 0.90 :       471 elements
# Info    : 0.90 < quality < 1.00 :       261 elements
# Info    : 59 edge swaps, 0 node relocations (volume = 2203.43): worst = 0.301813 / average = 0.722579 (Wall 0.000664966s, CPU 0.000697s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        40 elements
# Info    : 0.40 < quality < 0.50 :        91 elements
# Info    : 0.50 < quality < 0.60 :       274 elements
# Info    : 0.60 < quality < 0.70 :       797 elements
# Info    : 0.70 < quality < 0.80 :      1088 elements
# Info    : 0.80 < quality < 0.90 :       480 elements
# Info    : 0.90 < quality < 1.00 :       260 elements
# Info    : Optimizing volume 5
# Info    : Optimization starts (volume = 356.725) with worst = 0.0710826 / average = 0.534904:
# Info    : 0.00 < quality < 0.10 :         4 elements
# Info    : 0.10 < quality < 0.20 :        10 elements
# Info    : 0.20 < quality < 0.30 :         5 elements
# Info    : 0.30 < quality < 0.40 :        56 elements
# Info    : 0.40 < quality < 0.50 :       997 elements
# Info    : 0.50 < quality < 0.60 :       269 elements
# Info    : 0.60 < quality < 0.70 :       222 elements
# Info    : 0.70 < quality < 0.80 :       229 elements
# Info    : 0.80 < quality < 0.90 :        48 elements
# Info    : 0.90 < quality < 1.00 :        30 elements
# Info    : 9 edge swaps, 4 node relocations (volume = 356.725): worst = 0.0710826 / average = 0.536487 (Wall 0.000239679s, CPU 0.000265s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         4 elements
# Info    : 0.10 < quality < 0.20 :         4 elements
# Info    : 0.20 < quality < 0.30 :         2 elements
# Info    : 0.30 < quality < 0.40 :        54 elements
# Info    : 0.40 < quality < 0.50 :       999 elements
# Info    : 0.50 < quality < 0.60 :       274 elements
# Info    : 0.60 < quality < 0.70 :       220 elements
# Info    : 0.70 < quality < 0.80 :       227 elements
# Info    : 0.80 < quality < 0.90 :        52 elements
# Info    : 0.90 < quality < 1.00 :        28 elements
# Info    : Optimizing volume 6
# Info    : Optimization starts (volume = 356.725) with worst = 0.0886292 / average = 0.531072:
# Info    : 0.00 < quality < 0.10 :         4 elements
# Info    : 0.10 < quality < 0.20 :        20 elements
# Info    : 0.20 < quality < 0.30 :        11 elements
# Info    : 0.30 < quality < 0.40 :        75 elements
# Info    : 0.40 < quality < 0.50 :       969 elements
# Info    : 0.50 < quality < 0.60 :       283 elements
# Info    : 0.60 < quality < 0.70 :       212 elements
# Info    : 0.70 < quality < 0.80 :       238 elements
# Info    : 0.80 < quality < 0.90 :        57 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : 6 edge swaps, 7 node relocations (volume = 356.725): worst = 0.0886292 / average = 0.531707 (Wall 0.000320128s, CPU 0.000341s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         4 elements
# Info    : 0.10 < quality < 0.20 :        18 elements
# Info    : 0.20 < quality < 0.30 :         8 elements
# Info    : 0.30 < quality < 0.40 :        78 elements
# Info    : 0.40 < quality < 0.50 :       968 elements
# Info    : 0.50 < quality < 0.60 :       281 elements
# Info    : 0.60 < quality < 0.70 :       216 elements
# Info    : 0.70 < quality < 0.80 :       236 elements
# Info    : 0.80 < quality < 0.90 :        56 elements
# Info    : 0.90 < quality < 1.00 :        20 elements
# Info    : Optimizing volume 7
# Info    : Optimization starts (volume = 356.725) with worst = 0.00707157 / average = 0.533633:
# Info    : 0.00 < quality < 0.10 :        14 elements
# Info    : 0.10 < quality < 0.20 :        11 elements
# Info    : 0.20 < quality < 0.30 :         5 elements
# Info    : 0.30 < quality < 0.40 :        46 elements
# Info    : 0.40 < quality < 0.50 :       974 elements
# Info    : 0.50 < quality < 0.60 :       288 elements
# Info    : 0.60 < quality < 0.70 :       212 elements
# Info    : 0.70 < quality < 0.80 :       241 elements
# Info    : 0.80 < quality < 0.90 :        58 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : 18 edge swaps, 3 node relocations (volume = 356.725): worst = 0.0482709 / average = 0.537789 (Wall 0.000330058s, CPU 0.000351s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :         9 elements
# Info    : 0.20 < quality < 0.30 :         2 elements
# Info    : 0.30 < quality < 0.40 :        49 elements
# Info    : 0.40 < quality < 0.50 :       973 elements
# Info    : 0.50 < quality < 0.60 :       286 elements
# Info    : 0.60 < quality < 0.70 :       216 elements
# Info    : 0.70 < quality < 0.80 :       239 elements
# Info    : 0.80 < quality < 0.90 :        57 elements
# Info    : 0.90 < quality < 1.00 :        20 elements
# Info    : Done optimizing mesh (Wall 0.0103745s, CPU 0.011089s)
# Info    : 3109 nodes 20990 elements
# Info    : Meshing order 2 (curvilinear on)...
# Info    : [  0%] Meshing curve 13 order 2
# Info    : [ 10%] Meshing curve 14 order 2
# Info    : [ 10%] Meshing curve 15 order 2
# Info    : [ 10%] Meshing curve 16 order 2
# Info    : [ 10%] Meshing curve 17 order 2
# Info    : [ 10%] Meshing curve 18 order 2
# Info    : [ 10%] Meshing curve 19 order 2
# Info    : [ 10%] Meshing curve 20 order 2
# Info    : [ 10%] Meshing curve 21 order 2
# Info    : [ 10%] Meshing curve 22 order 2
# Info    : [ 10%] Meshing curve 23 order 2
# Info    : [ 20%] Meshing curve 24 order 2
# Info    : [ 20%] Meshing curve 25 order 2
# Info    : [ 20%] Meshing curve 26 order 2
# Info    : [ 20%] Meshing curve 27 order 2
# Info    : [ 20%] Meshing curve 28 order 2
# Info    : [ 20%] Meshing curve 29 order 2
# Info    : [ 20%] Meshing curve 30 order 2
# Info    : [ 20%] Meshing curve 31 order 2
# Info    : [ 20%] Meshing curve 32 order 2
# Info    : [ 20%] Meshing curve 33 order 2
# Info    : [ 30%] Meshing curve 34 order 2
# Info    : [ 30%] Meshing curve 35 order 2
# Info    : [ 30%] Meshing curve 36 order 2
# Info    : [ 30%] Meshing curve 37 order 2
# Info    : [ 30%] Meshing curve 38 order 2
# Info    : [ 30%] Meshing curve 39 order 2
# Info    : [ 30%] Meshing curve 40 order 2
# Info    : [ 30%] Meshing curve 41 order 2
# Info    : [ 30%] Meshing curve 42 order 2
# Info    : [ 30%] Meshing curve 43 order 2
# Info    : [ 40%] Meshing curve 44 order 2
# Info    : [ 40%] Meshing curve 45 order 2
# Info    : [ 40%] Meshing curve 46 order 2
# Info    : [ 40%] Meshing curve 47 order 2
# Info    : [ 40%] Meshing curve 48 order 2
# Info    : [ 40%] Meshing curve 49 order 2
# Info    : [ 40%] Meshing curve 50 order 2
# Info    : [ 40%] Meshing curve 51 order 2
# Info    : [ 40%] Meshing curve 52 order 2
# Info    : [ 40%] Meshing curve 53 order 2
# Info    : [ 40%] Meshing curve 54 order 2
# Info    : [ 50%] Meshing curve 55 order 2
# Info    : [ 50%] Meshing curve 56 order 2
# Info    : [ 50%] Meshing curve 57 order 2
# Info    : [ 50%] Meshing curve 58 order 2
# Info    : [ 50%] Meshing curve 59 order 2
# Info    : [ 50%] Meshing curve 60 order 2
# Info    : [ 50%] Meshing curve 61 order 2
# Info    : [ 50%] Meshing curve 62 order 2
# Info    : [ 50%] Meshing curve 63 order 2
# Info    : [ 50%] Meshing curve 64 order 2
# Info    : [ 60%] Meshing curve 65 order 2
# Info    : [ 60%] Meshing curve 66 order 2
# Info    : [ 60%] Meshing curve 67 order 2
# Info    : [ 60%] Meshing curve 68 order 2
# Info    : [ 60%] Meshing curve 69 order 2
# Info    : [ 60%] Meshing curve 70 order 2
# Info    : [ 60%] Meshing curve 71 order 2
# Info    : [ 60%] Meshing curve 72 order 2
# Info    : [ 60%] Meshing surface 7 order 2
# Info    : [ 60%] Meshing surface 8 order 2
# Info    : [ 70%] Meshing surface 9 order 2
# Info    : [ 70%] Meshing surface 10 order 2
# Info    : [ 70%] Meshing surface 11 order 2
# Info    : [ 70%] Meshing surface 12 order 2
# Info    : [ 70%] Meshing surface 13 order 2
# Info    : [ 70%] Meshing surface 14 order 2
# Info    : [ 70%] Meshing surface 15 order 2
# Info    : [ 70%] Meshing surface 16 order 2
# Info    : [ 70%] Meshing surface 17 order 2
# Info    : [ 70%] Meshing surface 18 order 2
# Info    : [ 70%] Meshing surface 19 order 2
# Info    : [ 80%] Meshing surface 20 order 2
# Info    : [ 80%] Meshing surface 21 order 2
# Info    : [ 80%] Meshing surface 22 order 2
# Info    : [ 80%] Meshing surface 23 order 2
# Info    : [ 80%] Meshing surface 24 order 2
# Info    : [ 80%] Meshing surface 25 order 2
# Info    : [ 80%] Meshing surface 26 order 2
# Info    : [ 80%] Meshing surface 27 order 2
# Info    : [ 80%] Meshing surface 28 order 2
# Info    : [ 80%] Meshing surface 29 order 2
# Info    : [ 90%] Meshing surface 30 order 2
# Info    : [ 90%] Meshing surface 31 order 2
# Info    : [ 90%] Meshing surface 32 order 2
# Info    : [ 90%] Meshing surface 33 order 2
# Info    : [ 90%] Meshing surface 34 order 2
# Info    : [ 90%] Meshing surface 35 order 2
# Info    : [ 90%] Meshing surface 36 order 2
# Info    : [ 90%] Meshing surface 37 order 2
# Info    : [ 90%] Meshing surface 38 order 2
# Info    : [ 90%] Meshing surface 39 order 2
# Info    : [100%] Meshing surface 40 order 2
# Info    : [100%] Meshing surface 41 order 2
# Info    : [100%] Meshing surface 42 order 2
# Info    : [100%] Meshing volume 1 order 2
# Info    : [100%] Meshing volume 2 order 2
# Info    : [100%] Meshing volume 3 order 2
# Info    : [100%] Meshing volume 4 order 2
# Info    : [100%] Meshing volume 5 order 2
# Info    : [100%] Meshing volume 6 order 2
# Info    : [100%] Meshing volume 7 order 2
# Info    : Surface mesh: worst distortion = 1 (0 elements in ]0, 0.2]); worst gamma = 0.355278
# Info    : Volume mesh: worst distortion = 1 (0 elements in ]0, 0.2])
# Info    : Done meshing order 2 (Wall 0.0424307s, CPU 0.043474s)
# Info    : Writing 'output/TFP6/geo/composite_layers.inp'...
# Info    : Done writing 'output/TFP6/geo/composite_layers.inp'
# Running Calculix at:  output/TFP6/sim
# Output file:  /home/djoroya/projects/CITISENS/CITISENS_Composite/scripts/T02_Modelo_MultiCapa/T02_NumericalModel/output/TFP6/sim/out.txt
# Command:
#  wine /home/djoroya/projects/CITISENS/CITISENS_Composite/src/djccx/bin/ccx_dynamic.exe main > out.txt
# Error reading cvf file
#
# pid:  1403349
#
# Calculix finished
#
# ['SY', 'X', 'Y', 'nucleo', 'Y', 'X', 'SY']
# Time Step:
# Time Step:
# Time Step:
# Running Calculix at:  output/TFP6/tensile
# Output file:  /home/djoroya/projects/CITISENS/CITISENS_Composite/scripts/T02_Modelo_MultiCapa/T02_NumericalModel/output/TFP6/tensile/out.txt
# Command:
#  wine /home/djoroya/projects/CITISENS/CITISENS_Composite/src/djccx/bin/ccx_dynamic.exe main > out.txt
# Error reading cvf file
#
# pid:  1403571
#
# Calculix finished
#
# ['SY', 'X', 'Y', 'nucleo', 'Y', 'X', 'SY']

# %%
df_stats["Eb pred [GPa]"]  = [ iall_params["Eflex"] for iall_params in all_params]
df_stats["Et pred [GPa]"]  = [ iall_params["Etensile"] for iall_params in all_params]
df_stats["Eb analytical pred [GPa]"]  = [ iall_params["Eflexion_analytical"] for iall_params in all_params]
df_stats["Et analytical pred [GPa]"]  = [ iall_params["Etensile_analytical"] for iall_params in all_params]
df_stats["St pred [MPa]"] = [ iall_params["rpost"]["S_prediction"] for iall_params in all_params]
df_stats["Sb pred [MPa]"] = [ iall_params["rpostbending"] for iall_params in all_params]

df_stats["St analytical pred [MPa]"] = [ 1e3*iall_params["St_analytical"] for iall_params in all_params]
df_stats["Sb analytical pred [MPa]"] = [ iall_params["Sb_analytical"] for iall_params in all_params]

tau_pred  = [ iall_params["geo"]["t_t"] for iall_params in all_params]
df_stats["t pred [mm]"] = tau_pred

# %%
df_stats.columns
# Out:
# MultiIndex([(                'Et [GPa]', 'mean'),
#             (                'Et [GPa]',  'std'),
#             (                     '% e', 'mean'),
#             (                     '% e',  'std'),
#             (                'St [MPa]', 'mean'),
#             (                'St [MPa]',  'std'),
#             (                'Eb [GPa]', 'mean'),
#             (                'Eb [GPa]',  'std'),
#             (                  't [mm]', 'mean'),
#             (                  't [mm]',  'std'),
#             (                  'b [mm]', 'mean'),
#             (                  'b [mm]',  'std'),
#             (                'Sb [MPa]', 'mean'),
#             (                'Sb [MPa]',  'std'),
#             (                  'layers',     ''),
#             (                      'Vc',     ''),
#             (           'Eb pred [GPa]',     ''),
#             (           'Et pred [GPa]',     ''),
#             ('Eb analytical pred [GPa]',     ''),
#             ('Et analytical pred [GPa]',     ''),
#             (           'St pred [MPa]',     ''),
#             (           'Sb pred [MPa]',     ''),
#             ('St analytical pred [MPa]',     ''),
#             ('Sb analytical pred [MPa]',     ''),
#             (             't pred [mm]',     '')],
#            )

# %%
from matplotlib import pyplot as plt

# %%
# plot bars with error bars Espesor (mm)
width = 0.3
idx = df_stats.index
idx_range = np.arange(len(idx))

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(131)

plt.bar(idx_range+width , 
        df_stats['t [mm]']['mean'], 
        yerr  = df_stats['t [mm]']['std'], 
        label ='Experimental',
        width = width)

plt.bar(idx_range, tau_pred, 
        label='Predicted', 
        alpha=0.5, 
        width=width)
plt.title('Espesor (mm)')

plt.legend()
plt.xticks(rotation=45)
plt.xlabel('') 
plt.grid()
plt.xticks(idx_range, idx);

ax = fig.add_subplot(132)

# plot bars with error bars Modulo Tracción [MPa] and prediction

plt.bar(idx_range+width , 
        df_stats['Eb [GPa]']['mean'], 
        yerr  = df_stats['Eb [GPa]']['std'], 
        label = 'Experimental',
        width = width)

plt.bar(idx_range, df_stats['Eb pred [GPa]'], 
        label='Predicted', 
        alpha=0.5, 
        width=width)
plt.legend()
plt.grid()
# off xlabel
plt.xlabel('') 
plt.xticks(rotation=45)
# tick labels 
plt.xticks(idx_range, idx);

plt.title('Modulo Flexión [GPa]')

ax = fig.add_subplot(133)

# plot bars with error bars St [MPa] and prediction
Et_exp = df_stats["Et [GPa]"]["mean"]
Et_exp_err = df_stats["Et [GPa]"]["std"]

plt.bar(idx_range+width ,
         Et_exp, 
         yerr=Et_exp_err, label='Experimental',width=width)
plt.bar(idx_range, df_stats['Et pred [GPa]'], label='Predicted', alpha=0.5, width=width)
plt.legend()
plt.grid()
# off xlabel
plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Modulo Tracción [GPa]')
# Out:
# Text(0.5, 1.0, 'Modulo Tracción [GPa]')

# %%
df_stats
# Out:
#       Et [GPa]                 % e              St [MPa]             \
#           mean       std      mean       std        mean        std
# Name
# TFP1  2.885509  0.227295  0.123306  0.009827  279.103333  14.337700
# TFP2  2.258503  0.065626  0.087556  0.002840  153.360000   0.473181
# TFP3  2.000437  0.004435  0.087444  0.002164  137.113333   4.996812
# TFP4  2.451362  0.114353  0.095472  0.005491  184.396667   1.356515
# TFP5  1.626582  0.120272  0.089889  0.013757   99.990000   9.790138
# TFP6  1.739870  0.067515  0.089083  0.010304  104.513333   7.708893
#
#        Eb [GPa]              t [mm]            ...     Vc Eb pred [GPa]  \
#            mean       std      mean       std  ...
# Name                                           ...
# TFP1  13.201050  0.630858  5.266667  0.057735  ...  0.178     12.638060
# TFP2   9.869501  0.780113  4.700000  0.000000  ...  0.164      7.469023
# TFP3   9.222003  0.495965  4.833333  0.057735  ...  0.135      6.589787
# TFP4  10.181815  0.770635  4.700000  0.000000  ...  0.144      7.675802
# TFP5   6.143105  0.161637  5.700000  0.000000  ...  0.146      5.684219
# TFP6   7.798060  0.334186  5.600000  0.000000  ...  0.180      6.154480
#
#      Et pred [GPa] Eb analytical pred [GPa] Et analytical pred [GPa]  \
#
# Name
# TFP1      9.726767                13.363298                 8.851335
# TFP2      6.252854                 7.169692                 5.690103
# TFP3      5.737969                 6.251695                 5.221555
# TFP4      6.377511                 7.391934                 5.803536
# TFP5      5.838007                 5.572788                 5.312589
# TFP6      6.268337                 6.108679                 5.704179
#
#      St pred [MPa] Sb pred [MPa] St analytical pred [MPa]  \
#
# Name
# TFP1    277.659418    428.389999               277.655928
# TFP2    178.493634    325.830292               178.491823
# TFP3    148.646651    179.773734               148.645239
# TFP4    127.647461    164.581736               127.646136
# TFP5    116.849121    126.670032               116.847978
# TFP6    125.462257    137.324683               125.460841
#
#      Sb analytical pred [MPa] t pred [mm]
#
# Name
# TFP1                 0.419191       4.834
# TFP2                 0.279915       4.834
# TFP3                 0.177971       4.834
# TFP4                 0.162582       4.834
# TFP5                 0.122571       5.784
# TFP6                 0.134358       5.784
#
# [6 rows x 25 columns]

# %%
# plot bars with error bars Espesor (mm)
width = 0.3
idx = df_stats.index
idx_range = np.arange(len(idx))

fig = plt.figure(figsize=(9, 9))
# subplot 
fig.subplots_adjust(hspace=0.35, wspace=0.35)

ax = fig.add_subplot(222)

# plot bars with error bars Modulo Flexion [GPa] and prediction

plt.bar(idx_range+width , df_stats['Eb [GPa]']['mean'], yerr=df_stats['Eb [GPa]']['std'], label='Experimental',width=width)
plt.bar(idx_range, df_stats['Eb pred [GPa]'], label='FEM', alpha=0.5, width=width)

Eb_pred_1   = df_stats['Eb pred [GPa]'].values[0]
Eb_analytical_1 = df_stats['Eb analytical pred [GPa]'].values[0]
# factor = Eb_pred_1/Eb_analytical_1
# plt.bar(idx_range-width, factor*df_stats['Eb analytical pred [GPa]'], label='Analytical', alpha=0.5, width=width)

plt.bar(idx_range-width, df_stats['Eb analytical pred [GPa]'], label='Analytical', alpha=0.5, width=width)

plt.legend()
plt.grid()
# off xlabel
plt.xlabel('') 
plt.xticks(rotation=45)
# tick labels 
plt.xticks(idx_range, idx);

plt.title('Modulo Flexión [GPa]')

ax = fig.add_subplot(221)

# plot bars with error bars Modulo Tracción [MPa] and prediction
Et_exp = df_stats["Et [GPa]"]["mean"]
Et_exp_err = df_stats["Et [GPa]"]["std"]

plt.bar(idx_range+width , Et_exp, yerr=Et_exp_err, label='Experimental',width=width)
plt.bar(idx_range, df_stats['Et pred [GPa]'], label='FEM', alpha=0.5, width=width)
plt.bar(idx_range-width, df_stats['Et analytical pred [GPa]'], label='Analytical', alpha=0.5, width=width)
plt.legend()
plt.grid()
# off xlabel
plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Modulo Tracción [GPa]')


ax = fig.add_subplot(223)

# 
St_exp = df_stats["St [MPa]"]["mean"]
St_exp_err = df_stats["St [MPa]"]["std"]

plt.bar(idx_range+width , St_exp, yerr=St_exp_err, label='Experimental',width=width)
plt.bar(idx_range, df_stats['St pred [MPa]'], label='FEM', alpha=0.5, width=width)
plt.bar(idx_range-width, df_stats['St analytical pred [MPa]'], label='Analytical', alpha=0.5, width=width)

plt.legend()
plt.grid()
# off xlabel

plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Tensión máxima Tracción  [MPa]')
# ========================
ax = fig.add_subplot(224)

Sb_exp = df_stats["Sb [MPa]"]["mean"]
Sb_exp_err = df_stats["Sb [MPa]"]["std"]

plt.bar(idx_range+width , Sb_exp, yerr=Sb_exp_err, label='Experimental',width=width)
plt.bar(idx_range, df_stats['Sb pred [MPa]'], label='FEM', alpha=0.5, width=width)
plt.bar(idx_range-width, 1e3*df_stats['Sb analytical pred [MPa]'], label='Analytical', alpha=0.5, width=width)

plt.title('Tensión máxima Flexión [MPa]')
plt.xlabel('')
plt.xticks(rotation=45)
plt.xticks(idx_range, idx);
plt.legend()
plt.grid()

# %%
df_stats['Sb analytical pred [MPa]'].values*1e3
# Out:
# array([419.19091863, 279.91497134, 177.97086575, 162.582232  ,
#        122.57094946, 134.35763184])

# %%
# plot bars with error bars Espesor (mm)
width = 0.3
idx = df_stats.index
idx_range = np.arange(len(idx))

fig = plt.figure(figsize=(9, 7))
# subplot 
fig.subplots_adjust(hspace=0.35, wspace=0.35)

ax = fig.add_subplot(222)

# plot bars with error bars Modulo Flexion [GPa] and prediction

plt.bar(idx_range, df_stats['Eb pred [GPa]'], label='FEM', width=width)

Eb_pred_1   = df_stats['Eb pred [GPa]'].values[0]
Eb_analytical_1 = df_stats['Eb analytical pred [GPa]'].values[0]

plt.bar(idx_range-width, df_stats['Eb analytical pred [GPa]'], label='Analítico', width=width)

plt.legend()
plt.grid()
# off xlabel
plt.xlabel('') 
plt.xticks(rotation=45)
# tick labels 
plt.xticks(idx_range, idx);

plt.title('Modulo Flexión [GPa]')

ax = fig.add_subplot(221)

# plot bars with error bars Modulo Tracción [MPa] and prediction
Et_exp = df_stats["Et [GPa]"]["mean"]
Et_exp_err = df_stats["Et [GPa]"]["std"]

plt.bar(idx_range, df_stats['Et pred [GPa]'], label='FEM', width=width)
plt.bar(idx_range-width, df_stats['Et analytical pred [GPa]'], label='Analítico',  width=width)
plt.legend()
plt.grid()
# off xlabel
plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Modulo Tracción [GPa]')


ax = fig.add_subplot(223)

# 
St_exp = df_stats["St [MPa]"]["mean"]
St_exp_err = df_stats["St [MPa]"]["std"]

plt.bar(idx_range, df_stats['St pred [MPa]'], label='FEM', width=width)
plt.bar(idx_range-width, df_stats['St analytical pred [MPa]'], label='Analítico', width=width)

plt.legend()
plt.grid()
# off xlabel

plt.xlabel('')
plt.xticks(rotation=45)
# tick labels
plt.xticks(idx_range, idx);
plt.title('Tensión máxima Tracción  [MPa]')
# ========================
ax = fig.add_subplot(224)

Sb_exp = df_stats["Sb [MPa]"]["mean"]
Sb_exp_err = df_stats["Sb [MPa]"]["std"]

plt.bar(idx_range, df_stats['Sb pred [MPa]'], label='FEM', width=width)
plt.bar(idx_range-width, 1e3*df_stats['Sb analytical pred [MPa]'], label='Analítico', width=width)

plt.title('Tensión máxima Flexión [MPa]')
plt.xlabel('')
plt.xticks(rotation=45)
plt.xticks(idx_range, idx);
plt.legend()
plt.grid()

# %%
df_stats['Sb analytical pred [MPa]']*1e3
# Out:
# Name
# TFP1    419.190919
# TFP2    279.914971
# TFP3    177.970866
# TFP4    162.582232
# TFP5    122.570949
# TFP6    134.357632
# Name: Sb analytical pred [MPa], dtype: float64

# %%
Et_exp
# Out:
# Name
# TFP1    2.885509
# TFP2    2.258503
# TFP3    2.000437
# TFP4    2.451362
# TFP5    1.626582
# TFP6    1.739870
# Name: mean, dtype: float64

# %%
df_stats
# Out:
#       Et [GPa]                 % e              St [MPa]             \
#           mean       std      mean       std        mean        std
# Name
# TFP1  2.885509  0.227295  0.123306  0.009827  279.103333  14.337700
# TFP2  2.258503  0.065626  0.087556  0.002840  153.360000   0.473181
# TFP3  2.000437  0.004435  0.087444  0.002164  137.113333   4.996812
# TFP4  2.451362  0.114353  0.095472  0.005491  184.396667   1.356515
# TFP5  1.626582  0.120272  0.089889  0.013757   99.990000   9.790138
# TFP6  1.739870  0.067515  0.089083  0.010304  104.513333   7.708893
#
#        Eb [GPa]              t [mm]            ...     Vc Eb pred [GPa]  \
#            mean       std      mean       std  ...
# Name                                           ...
# TFP1  13.201050  0.630858  5.266667  0.057735  ...  0.178     12.638060
# TFP2   9.869501  0.780113  4.700000  0.000000  ...  0.164      7.469023
# TFP3   9.222003  0.495965  4.833333  0.057735  ...  0.135      6.589787
# TFP4  10.181815  0.770635  4.700000  0.000000  ...  0.144      7.675802
# TFP5   6.143105  0.161637  5.700000  0.000000  ...  0.146      5.684219
# TFP6   7.798060  0.334186  5.600000  0.000000  ...  0.180      6.154480
#
#      Et pred [GPa] Eb analytical pred [GPa] Et analytical pred [GPa]  \
#
# Name
# TFP1      9.726767                13.363298                 8.851335
# TFP2      6.252854                 7.169692                 5.690103
# TFP3      5.737969                 6.251695                 5.221555
# TFP4      6.377511                 7.391934                 5.803536
# TFP5      5.838007                 5.572788                 5.312589
# TFP6      6.268337                 6.108679                 5.704179
#
#      St pred [MPa] Sb pred [MPa] St analytical pred [MPa]  \
#
# Name
# TFP1    277.659418    428.389999               277.655928
# TFP2    178.493634    325.830292               178.491823
# TFP3    148.646651    179.773734               148.645239
# TFP4    127.647461    164.581736               127.646136
# TFP5    116.849121    126.670032               116.847978
# TFP6    125.462257    137.324683               125.460841
#
#      Sb analytical pred [MPa] t pred [mm]
#
# Name
# TFP1                 0.419191       4.834
# TFP2                 0.279915       4.834
# TFP3                 0.177971       4.834
# TFP4                 0.162582       4.834
# TFP5                 0.122571       5.784
# TFP6                 0.134358       5.784
#
# [6 rows x 25 columns]

# %%
df_save = pd.DataFrame({"Eb [GPa]"        : df_stats['Eb [GPa]']['mean'].values,
                        "Eb pred [GPa]"   : df_stats['Eb pred [GPa]'].values,
                        "Et [GPa]"        : df_stats["Et [GPa]"]["mean"].values,
                        "Et pred [GPa]"   : df_stats['Et pred [GPa]'].values,
                        "Name": df_stats.index})

df_save.to_csv("output.csv", index=False)

# %%
plt.plot(df_stats["Eb analytical pred [GPa]"],df_stats["Eb pred [GPa]"],'o')
plt.plot([0,15],[0,15],'r--')
plt.grid()
plt.ylabel("FEM")
plt.xlabel("Analytical")
plt.title("Modulo Flexión [GPa]")

for i in range(len(df_stats)):
    plt.text(df_stats["Eb analytical pred [GPa]"].iloc[i],
             df_stats["Eb pred [GPa]"].iloc[i],
             df_stats.index[i])
plt.xlim(0,25)
plt.ylim(0,25)
# Out:
# (0.0, 25.0)

# %%
params
# Out:
# {'El': array([ 5.198613,  2.814443, 21.28429 ,  5.775806]),
#  'geo': {'t_n': 2.934, 't_l': 0.475, 'Lx': 30, 'meshsizefactor': 0.85},
#  'sim': {'disp': 5.0,
#   'opt': {'OMP_NUM_THREADS': 4, 'mpi_np': 4, 'mpi': True},
#   'E_n': np.float64(800.0)},
#  'tensile': {'disp': 3.0,
#   'St_layers': {'X': 481.083731,
#    'SX': 80.120493,
#    'Y': 667.663085,
#    'SY': 127.036236,
#    'nucleo': 0.0}}}

# %%
El = df_layers.loc["Y"].values
En = df_layers.loc["nucleo"].values
tn = params["geo"]["t_n"]
tl = params["geo"]["t_l"]

# %%
print("El", El)
print("En", En)
print("tn", tn)
print("tl", tl)
# Out:
# El [21.28429]
# En [0.8]
# tn 2.934
# tl 0.475

# %%
E_eff = (En*tn + 2*(2*El*tl)) / (tn + 2*(2*tl))
print(E_eff)
# Out:
# [8.85133451]
