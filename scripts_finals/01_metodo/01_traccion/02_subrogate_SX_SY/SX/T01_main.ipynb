# %%
import os 
from copy import deepcopy
from FEM_traccion.RunFullModel import RunFullModel
import numpy as np
join = os.path.join

A_s = 0.283 # mm^2

# %%
t_l = 0.475 #  Espesor de la capa [mm]
t_n = 2.934

r = 3*t_l/8 
d = (A_s - np.pi*r**2)/(2*r) # Area de la capa [mm^2]
params_composite ={
    "r"         :  r,
    "d"         :  d,
    "h"         :  t_l,
    "z0"        :  0,
    "density"   : 5,
}

params_ccx = {
    "epsilon" : 0.1,
    "x_fixed" : True
}
params = {
    "mesh" : params_composite,
    "ccx"  : params_ccx,
}

# %%
params
# Out:
# {'mesh': {'r': 0.17812499999999998,
#   'd': 0.5145878692019398,
#   'h': 0.475,
#   'z0': 0,
#   'density': 5},
#  'ccx': {'epsilon': 0.1, 'x_fixed': True}}

# %%
1.05/3
# Out:
# 0.35000000000000003

# %%
E_Resina =  3.59*1e3 
E_Carbon =  86.75*1e3

params["ccx"]["E_carbon"] = E_Carbon
params["ccx"]["nu"] = 0.3
params["ccx"]["E_resina"] = E_Resina
params["ccx"]["nu_resina"] = 0.3

E_r_linspace = np.linspace(0.5*E_Resina, 1.5*E_Resina, 4)
E_c_linspace = np.linspace(0.5*E_Carbon, 1.5*E_Carbon, 4)

E_r_ms, E_c_ms = np.meshgrid(E_r_linspace, E_c_linspace)

E_pairs = []
for i in range(E_r_ms.shape[0]):
    for j in range(E_r_ms.shape[1]):
        E_pairs.append((E_r_ms[i,j], E_c_ms[i,j]))
E_pairs = np.array(E_pairs)

# %%
# remove output folder if exists
output_folder = "output"
import os
if os.path.exists(output_folder):
    import shutil
    shutil.rmtree(output_folder)

# %%
output = join("output")
RunFullModel("SX",output,params,E_pairs)
# Out:
# 	==================================================
# 	Design SX
# 	==================================================
# Layer number 1/1 done
# Meshing ...
# 	==================================================
# 	CCX SX
# 	==================================================
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_00
# Resina E:  1795.0
# Carbon E:  43375.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_00
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_00\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  11928
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_01
# Resina E:  2991.666666666667
# Carbon E:  43375.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_01
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_01\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  4712
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_02
# Resina E:  4188.333333333334
# Carbon E:  43375.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_02
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_02\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  12360
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_03
# Resina E:  5385.0
# Carbon E:  43375.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_03
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_03\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  14912
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_04
# Resina E:  1795.0
# Carbon E:  72291.66666666667
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_04
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_04\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  14092
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_05
# Resina E:  2991.666666666667
# Carbon E:  72291.66666666667
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_05
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_05\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  12108
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_06
# Resina E:  4188.333333333334
# Carbon E:  72291.66666666667
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_06
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_06\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  14304
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_07
# Resina E:  5385.0
# Carbon E:  72291.66666666667
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_07
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_07\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  13936
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_08
# Resina E:  1795.0
# Carbon E:  101208.33333333334
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_08
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_08\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  14176
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_09
# Resina E:  2991.666666666667
# Carbon E:  101208.33333333334
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_09
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_09\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  5072
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_10
# Resina E:  4188.333333333334
# Carbon E:  101208.33333333334
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_10
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_10\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  6652
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_11
# Resina E:  5385.0
# Carbon E:  101208.33333333334
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_11
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_11\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  14316
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_12
# Resina E:  1795.0
# Carbon E:  130125.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_12
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_12\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  14748
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_13
# Resina E:  2991.666666666667
# Carbon E:  130125.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_13
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_13\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  6584
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_14
# Resina E:  4188.333333333334
# Carbon E:  130125.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_14
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_14\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  13184
#
# Calculix finished
#
# Input folder: 	 output\designs\SX
# Output folder: 	 output\ccx\SX\E_15
# Resina E:  5385.0
# Carbon E:  130125.0
# Nucleo E:  800
# Running Calculix at:  output\ccx\SX\E_15
# Output file:  c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\scripts_finals\01_metodo\01_traccion\02_subrogate_SX_SY\SX\output\ccx\SX\E_15\out.txt
# Command:
#  C:\Program Files\Microsoft MPI\Bin\mpiexec -n 6 c:\Users\djoroya\Documents\GitHub\CITISENS_Composite_v2\.conda\Lib\site-packages\djccx\bin\ccx_dynamic.exe main
# Error reading cvf file
#
# pid:  16988
#
# Calculix finished
